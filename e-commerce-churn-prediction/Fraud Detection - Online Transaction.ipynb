# %% [markdown]
# # E-Commerce Churn Prediction
#
# The **objective** of this project is to predict customer churn in an e-commerce dataset using machine learning techniques.
#
# The project aims to identify key features that influence customer churn and build a predictive model that can effectively classify churners and non-churners.

# %% [markdown]
# # Glossary of Features

# %% [markdown]
# This glossary defines and describes the features used in the customer churn prediction project.
#
# **TotalOrdersLast1Week:** Total number of orders placed by a customer in the last week.
#
# *Purpose:* Indicates recent purchase activity and potential customer engagement.
#
#
# **TotalAmountLast1Week:** Total monetary amount spent by a customer in the last week.
#
# *Purpose:* Reflects recent spending behavior and customer satisfaction.
#
#
# **TimeSinceLastOrder:** Number of days since the customer's last order.
#
# *Purpose:* Measures recency of engagement; longer times may indicate higher churn risk.
#
# **TotalOrdersLast1Month:** Total number of orders placed by a customer in the last month.
#
# *Purpose:* Captures medium-term purchasing behavior and trends.
#
# **TotalAmountLast1Month:** Total monetary amount spent by a customer in the last month.
#
# *Purpose:* Represents customer spending over a medium-term period.
#
# **MaxOrderAmount:** Highest single order amount made by the customer.
#
# *Purpose:* Identifies high-value customers.
#
# **MinOrderAmount:** Lowest single order amount made by the customer.
#
# *Purpose:* Provides insight into the range of spending behavior.
#
# **AverageOrderAmount:** Average amount spent per order by the customer.
#
# *Purpose:* Indicates typical spending levels.
#
# **TotalUniqueOrders:** Total number of unique orders placed by the customer.
#
# *Purpose:* Measures the breadth of customer engagement.
#
# **AverageOrderDuration:** Average duration between consecutive orders.
#
# *Purpose:* Reflects purchasing frequency.
#
# **DaysSinceFirstPurchase:** Number of days since the customer's first purchase.
#
# *Purpose:* Indicates customer tenure.
#
# **OrderStdDeviation:** Standard deviation of order amounts.
#
# *Purpose:* Measures variability in spending.
#
# **TotalPurchase:** Cumulative amount spent by the customer across all orders.
#
# *Purpose:* Represents overall customer value.
#
# **TotalOrderAmountLast30Days:** Total amount spent by the customer in the last 30 days.
#
# *Purpose:* Captures recent spending behavior.
#
#
# **TotalOrderQuantityLast30Days:** Total quantity of items ordered by the customer in the last 30 days.
#
# *Purpose:* Reflects recent purchasing volume.
#
# **MaxAmountLast30Days:** Highest order amount in the last 30 days.
#
# *Purpose:* Identifies significant recent transactions.
#
# **OverMaxAmountLast30Days:** Number of orders exceeding the maximum order amount in the last 30 days.
#
# *Purpose:* Highlights unusual spending spikes.
#
# **MinAmountPriorToDate:** Lowest order amount prior to the current date.
#
# *Purpose:* Provides historical context to spending patterns.
#
# **MeanAmountPriorToDate:** Average order amount prior to the current date.
#
# *Purpose:* Reflects typical historical spending levels.
#
# **PrevMeanAmount:** Previous average order amount before the most recent purchase.
#
# *Purpose:* Compares historical and current spending behavior.
#
# **CumulativeTime:** Total time since the customer's first purchase.
#
# *Purpose:* Measures overall duration of engagement.
#
# **PriorOrderCount:** Total number of orders placed by the customer before the most recent purchase.
#
# *Purpose:* Indicates historical purchasing frequency.
#
# **InvoiceYear:** Year when the invoice was generated.
#
# *Purpose:* Identifies temporal patterns in purchasing.
#
# **InvoiceMonth:** Month when the invoice was generated.
#
# *Purpose:* Useful for detecting seasonal trends.
#
# **InvoiceDay:** Day of the month when the invoice was generated.
#
# *Purpose:* Provides day-specific insights into purchasing activity.
#
# **InvoiceHour:** Hour of the day when the invoice was generated.
#
# *Purpose:* Identifies time-of-day purchasing patterns.
#
# **NextOrderYear:** Year of the next expected order based on historical data.
#
# *Purpose:* Useful for predicting future purchasing trends.
#
# **NextOrderMonth:** Month of the next expected order based on historical data.
#
# *Purpose:* Helps in forecasting customer behavior.
#
# **NextOrderDay:** Day of the next expected order based on historical data.
#
# *Purpose:* Assists in detailed forecasting.
#
#
# **NextOrderHour:** Hour of the next expected order based on historical data.
# *Purpose:* Provides granular insights for forecasting.
#
# **Country:** Country of the customer.
#
# *Purpose:* Useful for geographical segmentation and understanding regional trends.
#
# **UnitPrice:** Price per unit of the product purchased.
#
# *Purpose:* Helps in analyzing spending behavior at a granular level.
#
# **TotalAmountLast1Week:** Total amount spent by a customer in the last week.
#
# *Purpose:* Reflects recent spending behavior and customer satisfaction.
#
# **PrevMeanAmount:** Average order amount before the most recent purchase.
#
# *Purpose:* Compares historical and current spending behavior.

# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.tseries.offsets import DateOffset
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Loading and Preprocessing:
#
# Data loading and preprocessing for churn prediction.

# %%
df = pd.read_csv("OnlineRetail.csv")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB
# None

# %% [markdown]
#  "InvoiceDate" column is converted to the datetime data type. This makes it easier to work with date and time information.

# %%
# Convert InvoiceDate & NextOrderDate to datetime
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])

# %%
#The DataFrame is sorted by 'CustomerID' and 'InvoiceDate' using the sort_values() method.
df.sort_values(['CustomerID', 'InvoiceDate'], inplace=True)

# %%
# Drop rows with missing CustomerID
df.dropna(subset=["CustomerID"], inplace=True)

# %%
# Fill missing values in Description column with "Unknown"
df["Description"].fillna("Unknown", inplace=True)

# %%
# The "CustomerID" column is converted to an integer type using astype() for more efficient processing.
df["CustomerID"] = df["CustomerID"].astype(int)

# %%
print(df.head())
# Out:
#       InvoiceNo StockCode                        Description  Quantity  \
# 61619    541431     23166     MEDIUM CERAMIC TOP STORAGE JAR     74215
# 61624   C541433     23166     MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 14938    537626     85116    BLACK CANDELABRA T-LIGHT HOLDER        12
# 14939    537626     22375  AIRLINE BAG VINTAGE JET SET BROWN         4
# 14940    537626     71477  COLOUR GLASS. STAR T-LIGHT HOLDER        12
#
#               InvoiceDate  UnitPrice  CustomerID         Country
# 61619 2011-01-18 10:01:00       1.04       12346  United Kingdom
# 61624 2011-01-18 10:17:00       1.04       12346  United Kingdom
# 14938 2010-12-07 14:57:00       2.10       12347         Iceland
# 14939 2010-12-07 14:57:00       4.25       12347         Iceland
# 14940 2010-12-07 14:57:00       3.25       12347         Iceland

# %%
#The code then prints information about the DataFrame using the info() method, which provides details about the data types, non-null counts, and memory usage of each column.
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406829 entries, 61619 to 423941
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  datetime64[ns]
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  int64
#  7   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 27.9+ MB
# None

# %%
## Check for missing values and data types in the DataFrame and print the results.
missing_values = df.isnull().sum()
data_types = df.dtypes
print("Missing Values:")
print(missing_values)

print("\nData Types:")
print(data_types)
# Out:
# Missing Values:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64
#
# Data Types:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID              int64
# Country                object
# dtype: object

# %%
# Handle outliers using z-score
from scipy.stats import zscore

z_scores = zscore(df[["Quantity", "UnitPrice"]])
outliers = (z_scores < -3) | (z_scores > 3)
df[["Quantity", "UnitPrice"]] = np.where(outliers, np.nan, df[["Quantity", "UnitPrice"]])

# %% [markdown]
# Outliers in the "Quantity" and "UnitPrice" columns are handled using z-scores. Values with z-scores greater than the threshold (3) or less than negative the threshold are considered outliers. Outliers are either replaced with NaN or capped at a certain value using NumPy's np.where function

# %%
# Print the first few rows of the DataFrame to check
print("After handling outliers using z-score:")
print(df.head())
# Out:
# After handling outliers using z-score:
#       InvoiceNo StockCode                        Description  Quantity  \
# 61619    541431     23166     MEDIUM CERAMIC TOP STORAGE JAR       NaN
# 61624   C541433     23166     MEDIUM CERAMIC TOP STORAGE JAR       NaN
# 14938    537626     85116    BLACK CANDELABRA T-LIGHT HOLDER      12.0
# 14939    537626     22375  AIRLINE BAG VINTAGE JET SET BROWN       4.0
# 14940    537626     71477  COLOUR GLASS. STAR T-LIGHT HOLDER      12.0
#
#               InvoiceDate  UnitPrice  CustomerID         Country
# 61619 2011-01-18 10:01:00       1.04       12346  United Kingdom
# 61624 2011-01-18 10:17:00       1.04       12346  United Kingdom
# 14938 2010-12-07 14:57:00       2.10       12347         Iceland
# 14939 2010-12-07 14:57:00       4.25       12347         Iceland
# 14940 2010-12-07 14:57:00       3.25       12347         Iceland

# %% [markdown]
# # Advanced Feature Engineering
# In this process, we create features to understand customer behavior over time, particularly focusing on recency, frequency, and monetary value. These features are crucial for predicting customer churn, defined as customers who stop purchasing within a specific period (30 days in this case)

# %% [markdown]
# This defines a 30-day period to predict if a customer will churn.

# %%
# Define the prediction horizon (e.g., 30 days)
prediction_horizon = pd.Timedelta(days=30)

# %% [markdown]
# This column captures the date of the next order for each customer by shifting the invoice date backward within each customer group.

# %%
# Create a column 'NextOrderDate' with the next order date for each customer
df['NextOrderDate'] = df.groupby('CustomerID')['InvoiceDate'].shift(-1)

# %%
# Convert NextOrderDate to datetime
df['NextOrderDate'] = pd.to_datetime(df['NextOrderDate'])

# %% [markdown]
# The 'Churn' column shows if a customer will order again within 30 days. If the time difference between the current order and the next is less than or equal to 30 days, 'Churn' is set to True (not churned), otherwise False.

# %%
# Create a column 'Churn' indicating if a customer ordered in the next 30 days
df['Churn'] = (df.groupby('CustomerID')['NextOrderDate']
               .diff(-1) <= prediction_horizon)

# %% [markdown]
# This calculates the total amount spent for each order.

# %%
# Calculates the total purchase amount for each row
df['TotalPurchase'] = df['UnitPrice'] * df['Quantity']

# %% [markdown]
# These columns show the total order amount and quantity in the last 30 days for each customer, providing a rolling sum to capture recent activity.

# %%
# Calculates rolling sum for total order amount in the last 30 days for each customer.
#Ensures that at least one row is present for each calculation, even if there are data gaps.
df['TotalOrderAmountLast30Days'] = df.groupby('CustomerID')['TotalPurchase'].transform(
    lambda x: x.rolling(window=30, min_periods=1).sum())

# %%
# Calculates rolling sum for total order quantity in the last 30 days for each customer
df['TotalOrderQuantityLast30Days'] = df.groupby('CustomerID')['Quantity'].transform(
    lambda x: x.rolling(window=30, min_periods=1).sum())

# %% [markdown]
# This calculates the highest order amount in the last 30 days and then tracks the highest order amount across all past orders for each customer.

# %%
# Calculates the maximum order amount in the last 30 days for each customer
df['MaxOrderAmount'] = df.groupby('CustomerID')['UnitPrice'].transform(
    lambda x: x.rolling(window=30, min_periods=1).max())

# %%
# Calculates the cumulative maximum of MaxOrderAmount for each customer
df['MaxOrderAmount'] = df.groupby('CustomerID')['MaxOrderAmount'].cummax()

# %% [markdown]
# Resets the DataFrame index to ensure it starts from 0 and maintains consistency in the DataFrame.

# %%
# Reset index to maintain consistency in the DataFrame
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# Identifies whether customers are likely to stop buying within the next 30 days.
#
# **Total Order Amount & Quantity:** Provides insight into the customer's spending and purchase behavior over the past month.
#
# **Max Order Amount:** Tracks the highest order value over time, indicating the peak spending capacity of each customer.

# %% [markdown]
# Looking into individual customer histories to understand their behavior.

# %%
print(df[['CustomerID', 'InvoiceDate', 'Churn', 'TotalOrderAmountLast30Days', 'TotalOrderQuantityLast30Days']])
# Out:
#         CustomerID         InvoiceDate  Churn  TotalOrderAmountLast30Days  \
# 0            12346 2011-01-18 10:01:00  False                         NaN
# 1            12346 2011-01-18 10:17:00  False                         NaN
# 2            12347 2010-12-07 14:57:00   True                       25.20
# 3            12347 2010-12-07 14:57:00   True                       42.20
# 4            12347 2010-12-07 14:57:00   True                       81.20
# ...            ...                 ...    ...                         ...
# 406824       18287 2011-10-12 10:23:00   True                      842.92
# 406825       18287 2011-10-12 10:23:00   True                      838.12
# 406826       18287 2011-10-28 09:29:00   True                      857.68
# 406827       18287 2011-10-28 09:29:00  False                      867.04
# 406828       18287 2011-10-28 09:29:00  False                      855.28
#
#         TotalOrderQuantityLast30Days
# 0                                NaN
# 1                                NaN
# 2                               12.0
# 3                               16.0
# 4                               28.0
# ...                              ...
# 406824                         876.0
# 406825                         864.0
# 406826                         876.0
# 406827                         900.0
# 406828                         876.0
#
# [406829 rows x 5 columns]

# %%
# Drop rows with NaN values in TotalOrderAmountLast30Days and TotalOrderQuantityLast30Days
df.dropna(subset=['TotalOrderAmountLast30Days', 'TotalOrderQuantityLast30Days'], inplace=True)

# %%
print(df[['TotalOrderAmountLast30Days', 'TotalOrderQuantityLast30Days']])
# Out:
#         TotalOrderAmountLast30Days  TotalOrderQuantityLast30Days
# 2                            25.20                          12.0
# 3                            42.20                          16.0
# 4                            81.20                          28.0
# 5                           104.60                          64.0
# 6                           119.60                          76.0
# ...                            ...                           ...
# 406824                      842.92                         876.0
# 406825                      838.12                         864.0
# 406826                      857.68                         876.0
# 406827                      867.04                         900.0
# 406828                      855.28                         876.0
#
# [406789 rows x 2 columns]

# %% [markdown]
# # Feature Selection Target Definition 1: Early Churn (7-Day Window)
# This process prepares the data for early churn prediction by defining two target variables, 'Churn7Days' and 'Churn1Month'. These variables are needed for training predictive models that identify customers at risk of churn within specific time frames.

# %%
# Define the prediction horizon for Target 1 (7 days)
prediction_horizon_7_days = pd.Timedelta(days=7)

# %%
# Define the prediction horizon for Target 2 (30 days)
#this line sets the prediction horizon for 'Churn1Month' to 30 days, defining a 30-day window for predicting customer churn.
prediction_horizon_30_days = pd.Timedelta(days=30)

# %%
# Group by 'CustomerID' and create a 'NextOrderDate' column which stores the date of each customer's next order
df['NextOrderDate'] = df.groupby('CustomerID')['InvoiceDate'].shift(-1)

# Calculate 'Churn7Days' to indicate whether a customer churned within 7 days
df['Churn7Days'] = (df.groupby('CustomerID')['NextOrderDate'].diff(-1) > prediction_horizon_7_days).astype(int)

# %%
# The 'Churn1Month' column is created to indicate customer churn within a 30-day window.
#It applies a similar logic as 'Churn7Days' to determine whether a customer churned within 30 days.
df['Churn1Month'] = (df.groupby('CustomerID')['NextOrderDate'].diff(-1) > prediction_horizon_30_days).astype(int)

# %%
# Display the DataFrame with the new target variables
print(df[['CustomerID', 'InvoiceDate', 'Churn7Days', 'Churn1Month']])
# Out:
#         CustomerID         InvoiceDate  Churn7Days  Churn1Month
# 2            12347 2010-12-07 14:57:00           0            0
# 3            12347 2010-12-07 14:57:00           0            0
# 4            12347 2010-12-07 14:57:00           0            0
# 5            12347 2010-12-07 14:57:00           0            0
# 6            12347 2010-12-07 14:57:00           0            0
# ...            ...                 ...         ...          ...
# 406824       18287 2011-10-12 10:23:00           0            0
# 406825       18287 2011-10-12 10:23:00           0            0
# 406826       18287 2011-10-28 09:29:00           0            0
# 406827       18287 2011-10-28 09:29:00           0            0
# 406828       18287 2011-10-28 09:29:00           0            0
#
# [406789 rows x 4 columns]

# %% [markdown]
# # Feature Engineering
# Creating features that help understand and analyze customer behavior. These features include metrics like total orders, total amounts spent, time since the last order, rolling statistics, cumulative metrics, and more. These engineered features offer valuable insights into customer interactions, recency, frequency, and monetary behavior. By calculating rolling sums, maximums, minimums, averages, and standard deviations, we capture the dynamics of customer spending and engagement.

# %% [markdown]
# **Total Orders and Total Amount Spent**

# %%
# Define the number of data points in 1 week (assuming daily data)
one_week_window = 7

# %%
# Calculate the rolling sum of 'Quantity' for a 1-week window, giving the total number of orders placed by each customer in the last week
df['TotalOrdersLast1Week'] = df.groupby('CustomerID')['Quantity'].transform(
    lambda x: x.rolling(window=one_week_window, min_periods=1).sum())

# %%
# Calculate the rolling sum of 'UnitPrice' for a 1-week window, indicating the total amount spent by each customer in the last week
df['TotalAmountLast1Week'] = df.groupby('CustomerID')['UnitPrice'].transform(
    lambda x: x.rolling(window=one_week_window, min_periods=1).sum())

# %% [markdown]
# **Time Since Last Order**

# %%
# Calculates the time since the last order for each customer
#This line calculates the time in days since the last order for each customer. It helps in understanding the recency of customer interactions.

df['TimeSinceLastOrder'] = df.groupby('CustomerID')['InvoiceDate'].diff().dt.total_seconds() / (60 * 60 * 24)

# %% [markdown]
# **Total Orders and Total Amount Spent in Last 1 Month**

# %%
# Define the number of data points in 1 month (assuming 30 days in a month)
one_month_window = 30 

# Calculate the rolling sum of 'Quantity' for a 1-month window, giving the total number of orders placed by each customer in the last month
df['TotalOrdersLast1Month'] = df.groupby('CustomerID')['Quantity'].transform(
    lambda x: x.rolling(window=one_month_window, min_periods=1).sum())

# Calculates the rolling sum of 'UnitPrice' for a 1-month window, indicating the total amount spent by each customer in the last month
df['TotalAmountLast1Month'] = df.groupby('CustomerID')['UnitPrice'].transform(
    lambda x: x.rolling(window=one_month_window, min_periods=1).sum())

# %% [markdown]
# **Max Order Amount in Last 30 Days and Binary Indicator**

# %%
# Calculates the rolling 30-day maximum order amount for each customer
df['MaxAmountLast30Days'] = df.groupby('CustomerID')['TotalOrderAmountLast30Days'].rolling(window=30, min_periods=1).max().reset_index(level=0, drop=True)

# Creates a binary indicator to show if the current order amount exceeds the maximum order amount in the last 30 days
#This helps identify customers with a significant increase in spending.
df['OverMaxAmountLast30Days'] = (df['TotalOrderAmountLast30Days'] > df['MaxAmountLast30Days']).astype(int)

# %% [markdown]
# **Cumulative Metrics**

# %%
# Calculates the cumulative maximum order amount for each customer
#It provides insight into the highest order amount ever placed by a customer.
df['MaxOrderAmount'] = df.groupby('CustomerID')['UnitPrice'].transform(lambda x: x.expanding().max())

# Calculates the cumulative minimum order amount for each customer
df['MinAmountPriorToDate'] = df.groupby('CustomerID')['TotalOrderAmountLast30Days'].cummin()

# Calculates the cumulative mean order amount for each customer. It indicates the average spending behavior of a customer over time.
df['MeanAmountPriorToDate'] = df.groupby('CustomerID')['TotalOrderAmountLast30Days'].expanding().mean().reset_index(level=0, drop=True)

# %% [markdown]
# **Other Features**

# %%
# Calculates the minimum order amount (minimum of 'UnitPrice') for each customer.
df['MinOrderAmount'] = df.groupby('CustomerID')['UnitPrice'].transform('min')

# Computes the cumulative mean of 'TotalAmountLast1Month' for each customer, revealing the average spending trend over time.
df['PrevMeanAmount'] = df.groupby('CustomerID')['TotalAmountLast1Month'].expanding().mean().reset_index(level=0, drop=True)

# Calculates the cumulative sum of time differences (total time since the first order) for each customer, giving insights into customer loyalty and tenure.
df['CumulativeTime'] = df.groupby('CustomerID')['TimeSinceLastOrder'].cumsum()

# Calculates the count of prior orders for each customer, indicating how many orders they've placed so far.
df['PriorOrderCount'] = df.groupby('CustomerID').cumcount()

# Computes the average duration between prior orders placed by each customer.
df['AverageOrderDuration'] = df['CumulativeTime'] / df['PriorOrderCount']

# Calculates the average order amount (average of 'UnitPrice') for each customer.
df['AverageOrderAmount'] = df.groupby('CustomerID')['UnitPrice'].transform('mean')

# Calculates the total number of unique orders for each customer
df['TotalUniqueOrders'] = df.groupby('CustomerID')['InvoiceNo'].transform('nunique')

# Calculate the average duration between orders for each customer
df['AverageOrderDuration'] = df.groupby('CustomerID')['InvoiceDate'].diff().dt.total_seconds().mean() / (60 * 60 * 24)

# Calculates the number of days since the first purchase for each customer
df['DaysSinceFirstPurchase'] = (df['InvoiceDate'] - df.groupby('CustomerID')['InvoiceDate'].transform('min')).dt.days

# Calculates the rolling standard deviation of the 'TotalOrderAmountLast30Days' column for each CustomerID
df['PreviousStdDevTotalOrderAmount'] = df.groupby('CustomerID')['TotalOrderAmountLast30Days'].rolling(window=30).std().reset_index(level=0, drop=True)

# Calculates the standard deviation of orders for each customer
df['OrderStdDeviation'] = df.groupby('CustomerID')['Quantity'].transform('std')

# %%
# Display the DataFrame with the new columns
print(df[['CustomerID', 'InvoiceDate', 'UnitPrice', 'MinOrderAmount', 'PrevMeanAmount', 
         'CumulativeTime', 'PriorOrderCount', 'AverageOrderDuration', 'AverageOrderAmount', 
         'TotalUniqueOrders', 'DaysSinceFirstPurchase', 'PreviousStdDevTotalOrderAmount', 'OrderStdDeviation']])
# Out:
#         CustomerID         InvoiceDate  UnitPrice  MinOrderAmount  \
# 2            12347 2010-12-07 14:57:00       2.10            0.25
# 3            12347 2010-12-07 14:57:00       4.25            0.25
# 4            12347 2010-12-07 14:57:00       3.25            0.25
# 5            12347 2010-12-07 14:57:00       0.65            0.25
# 6            12347 2010-12-07 14:57:00       1.25            0.25
# ...            ...                 ...        ...             ...
# 406824       18287 2011-10-12 10:23:00       0.42            0.29
# 406825       18287 2011-10-12 10:23:00       2.10            0.29
# 406826       18287 2011-10-28 09:29:00       1.25            0.29
# 406827       18287 2011-10-28 09:29:00       0.39            0.29
# 406828       18287 2011-10-28 09:29:00       0.29            0.29
#
#         PrevMeanAmount  CumulativeTime  PriorOrderCount  AverageOrderDuration  \
# 2             2.100000             NaN                0              1.450278
# 3             4.225000        0.000000                1              1.450278
# 4             6.016667        0.000000                2              1.450278
# 5             7.075000        0.000000                3              1.450278
# 6             7.960000        0.000000                4              1.450278
# ...                ...             ...              ...                   ...
# 406824       38.214545      142.988889               65              1.450278
# 406825       38.151642      142.988889               66              1.450278
# 406826       38.093382      158.951389               67              1.450278
# 406827       38.036812      158.951389               68              1.450278
# 406828       37.980429      158.951389               69              1.450278
#
#         AverageOrderAmount  TotalUniqueOrders  DaysSinceFirstPurchase  \
# 2                 2.644011                  7                       0
# 3                 2.644011                  7                       0
# 4                 2.644011                  7                       0
# 5                 2.644011                  7                       0
# 6                 2.644011                  7                       0
# ...                    ...                ...                     ...
# 406824            1.493571                  3                     142
# 406825            1.493571                  3                     142
# 406826            1.493571                  3                     158
# 406827            1.493571                  3                     158
# 406828            1.493571                  3                     158
#
#         PreviousStdDevTotalOrderAmount  OrderStdDeviation
# 2                                  NaN          18.856172
# 3                                  NaN          18.856172
# 4                                  NaN          18.856172
# 5                                  NaN          18.856172
# 6                                  NaN          18.856172
# ...                                ...                ...
# 406824                       52.365471          14.206434
# 406825                       52.783579          14.206434
# 406826                       53.659747          14.206434
# 406827                       54.990301          14.206434
# 406828                       55.748495          14.206434
#
# [406789 rows x 13 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# In this section, performed a comprehensive EDA to gain insights into the dataset, which is vital for understanding customer behavior and preparing the data for further analysis, specifically in the context of customer churn prediction.

# %% [markdown]
# **After adding new columns, missing values in the dataset were identified and resolved to maintain data integrity for analysis.**
#
# **Initial Assessment:** The presence of missing values was assessed across all columns in the dataset.
#
# **Identification of Missing Values:** Columns with missing values were identified, and the extent of missingness was quantified.
#
# **Decision Making**: Based on the extent of missing values and the importance of the features, decisions were made on how to handle missing data.
#
# **Handling Missing Values:**
#
# Rows containing missing values in columns such as **'TotalPurchase'** and **'OrderStdDeviation'** were removed, as the number of missing values was relatively small compared to the overall dataset.
#
# The entire column **'PreviousStdDevTotalOrderAmount'** was dropped due to a high percentage of missing values, which would have limited its utility in analysis.
#
# For columns such as **'TimeSinceLastOrder' and 'CumulativeTime'**, rows with missing values were dropped since imputing these time-based features could introduce bias.
#
# After handling missing values, a final check was conducted to ensure that no missing values remained in the dataset.

# %%
# Check for NaN values in the DataFrame
nan_summary = df.isna().sum()

# Display the summary of NaN values
print(nan_summary)
# Out:
# InvoiceNo                              0
# StockCode                              0
# Description                            0
# Quantity                             161
# InvoiceDate                            0
# UnitPrice                            136
# CustomerID                             0
# Country                                0
# NextOrderDate                       4357
# Churn                                  0
# TotalPurchase                        297
# TotalOrderAmountLast30Days             0
# TotalOrderQuantityLast30Days           0
# MaxOrderAmount                         0
# Churn7Days                             0
# Churn1Month                            0
# TotalOrdersLast1Week                   0
# TotalAmountLast1Week                   0
# TimeSinceLastOrder                  4357
# TotalOrdersLast1Month                  0
# TotalAmountLast1Month                  0
# MaxAmountLast30Days                    0
# OverMaxAmountLast30Days                0
# MinAmountPriorToDate                   0
# MeanAmountPriorToDate                  0
# MinOrderAmount                         0
# PrevMeanAmount                         0
# CumulativeTime                      4357
# PriorOrderCount                        0
# AverageOrderDuration                   0
# AverageOrderAmount                     0
# TotalUniqueOrders                      0
# DaysSinceFirstPurchase                 0
# PreviousStdDevTotalOrderAmount    100890
# OrderStdDeviation                     73
# dtype: int64

# %%
# Bar plot of missing values
missing_data_percentage = df.isnull().mean() * 100
missing_data_percentage[missing_data_percentage > 0].sort_values().plot(kind='barh')
plt.xlabel('Percentage of Missing Data')
plt.show()
print(missing_data_percentage)
# Out:
# InvoiceNo                          0.000000
# StockCode                          0.000000
# Description                        0.000000
# Quantity                           0.039578
# InvoiceDate                        0.000000
# UnitPrice                          0.033433
# CustomerID                         0.000000
# Country                            0.000000
# NextOrderDate                      1.071071
# Churn                              0.000000
# TotalPurchase                      0.073011
# TotalOrderAmountLast30Days         0.000000
# TotalOrderQuantityLast30Days       0.000000
# MaxOrderAmount                     0.000000
# Churn7Days                         0.000000
# Churn1Month                        0.000000
# TotalOrdersLast1Week               0.000000
# TotalAmountLast1Week               0.000000
# TimeSinceLastOrder                 1.071071
# TotalOrdersLast1Month              0.000000
# TotalAmountLast1Month              0.000000
# MaxAmountLast30Days                0.000000
# OverMaxAmountLast30Days            0.000000
# MinAmountPriorToDate               0.000000
# MeanAmountPriorToDate              0.000000
# MinOrderAmount                     0.000000
# PrevMeanAmount                     0.000000
# CumulativeTime                     1.071071
# PriorOrderCount                    0.000000
# AverageOrderDuration               0.000000
# AverageOrderAmount                 0.000000
# TotalUniqueOrders                  0.000000
# DaysSinceFirstPurchase             0.000000
# PreviousStdDevTotalOrderAmount    24.801556
# OrderStdDeviation                  0.017945
# dtype: float64

# %%
# Create a DataFrame that indicates whether each value is missing
missing_data = df.isnull()

# Calculate the correlation matrix for the missing data
missing_corr = missing_data.corr()

# Plotting the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(missing_corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Missing Values')
plt.show()

# Display the actual correlation matrix for missing data
print("Correlation matrix for missing data:\n", missing_corr)
# Out:
# Correlation matrix for missing data:
#                                  InvoiceNo  StockCode  Description  Quantity  \
# InvoiceNo                             NaN        NaN          NaN       NaN
# StockCode                             NaN        NaN          NaN       NaN
# Description                           NaN        NaN          NaN       NaN
# Quantity                              NaN        NaN          NaN  1.000000
# InvoiceDate                           NaN        NaN          NaN       NaN
# UnitPrice                             NaN        NaN          NaN -0.000364
# CustomerID                            NaN        NaN          NaN       NaN
# Country                               NaN        NaN          NaN       NaN
# NextOrderDate                         NaN        NaN          NaN  0.011137
# Churn                                 NaN        NaN          NaN       NaN
# TotalPurchase                         NaN        NaN          NaN  0.736143
# TotalOrderAmountLast30Days            NaN        NaN          NaN       NaN
# TotalOrderQuantityLast30Days          NaN        NaN          NaN       NaN
# MaxOrderAmount                        NaN        NaN          NaN       NaN
# Churn7Days                            NaN        NaN          NaN       NaN
# Churn1Month                           NaN        NaN          NaN       NaN
# TotalOrdersLast1Week                  NaN        NaN          NaN       NaN
# TotalAmountLast1Week                  NaN        NaN          NaN       NaN
# TimeSinceLastOrder                    NaN        NaN          NaN -0.002070
# TotalOrdersLast1Month                 NaN        NaN          NaN       NaN
# TotalAmountLast1Month                 NaN        NaN          NaN       NaN
# MaxAmountLast30Days                   NaN        NaN          NaN       NaN
# OverMaxAmountLast30Days               NaN        NaN          NaN       NaN
# MinAmountPriorToDate                  NaN        NaN          NaN       NaN
# MeanAmountPriorToDate                 NaN        NaN          NaN       NaN
# MinOrderAmount                        NaN        NaN          NaN       NaN
# PrevMeanAmount                        NaN        NaN          NaN       NaN
# CumulativeTime                        NaN        NaN          NaN -0.002070
# PriorOrderCount                       NaN        NaN          NaN       NaN
# AverageOrderDuration                  NaN        NaN          NaN       NaN
# AverageOrderAmount                    NaN        NaN          NaN       NaN
# TotalUniqueOrders                     NaN        NaN          NaN       NaN
# DaysSinceFirstPurchase                NaN        NaN          NaN       NaN
# PreviousStdDevTotalOrderAmount        NaN        NaN          NaN  0.007747
# OrderStdDeviation                     NaN        NaN          NaN  0.008960
#
#                                 InvoiceDate  UnitPrice  CustomerID  Country  \
# InvoiceNo                               NaN        NaN         NaN      NaN
# StockCode                               NaN        NaN         NaN      NaN
# Description                             NaN        NaN         NaN      NaN
# Quantity                                NaN  -0.000364         NaN      NaN
# InvoiceDate                             NaN        NaN         NaN      NaN
# UnitPrice                               NaN   1.000000         NaN      NaN
# CustomerID                              NaN        NaN         NaN      NaN
# Country                                 NaN        NaN         NaN      NaN
# NextOrderDate                           NaN   0.013773         NaN      NaN
# Churn                                   NaN        NaN         NaN      NaN
# TotalPurchase                           NaN   0.676558         NaN      NaN
# TotalOrderAmountLast30Days              NaN        NaN         NaN      NaN
# TotalOrderQuantityLast30Days            NaN        NaN         NaN      NaN
# MaxOrderAmount                          NaN        NaN         NaN      NaN
# Churn7Days                              NaN        NaN         NaN      NaN
# Churn1Month                             NaN        NaN         NaN      NaN
# TotalOrdersLast1Week                    NaN        NaN         NaN      NaN
# TotalAmountLast1Week                    NaN        NaN         NaN      NaN
# TimeSinceLastOrder                      NaN  -0.001903         NaN      NaN
# TotalOrdersLast1Month                   NaN        NaN         NaN      NaN
# TotalAmountLast1Month                   NaN        NaN         NaN      NaN
# MaxAmountLast30Days                     NaN        NaN         NaN      NaN
# OverMaxAmountLast30Days                 NaN        NaN         NaN      NaN
# MinAmountPriorToDate                    NaN        NaN         NaN      NaN
# MeanAmountPriorToDate                   NaN        NaN         NaN      NaN
# MinOrderAmount                          NaN        NaN         NaN      NaN
# PrevMeanAmount                          NaN        NaN         NaN      NaN
# CumulativeTime                          NaN  -0.001903         NaN      NaN
# PriorOrderCount                         NaN        NaN         NaN      NaN
# AverageOrderDuration                    NaN        NaN         NaN      NaN
# AverageOrderAmount                      NaN        NaN         NaN      NaN
# TotalUniqueOrders                       NaN        NaN         NaN      NaN
# DaysSinceFirstPurchase                  NaN        NaN         NaN      NaN
# PreviousStdDevTotalOrderAmount          NaN  -0.000539         NaN      NaN
# OrderStdDeviation                       NaN  -0.000245         NaN      NaN
#
#                                 NextOrderDate  Churn  ...  MinOrderAmount  \
# InvoiceNo                                 NaN    NaN  ...             NaN
# StockCode                                 NaN    NaN  ...             NaN
# Description                               NaN    NaN  ...             NaN
# Quantity                             0.011137    NaN  ...             NaN
# InvoiceDate                               NaN    NaN  ...             NaN
# UnitPrice                            0.013773    NaN  ...             NaN
# CustomerID                                NaN    NaN  ...             NaN
# Country                                   NaN    NaN  ...             NaN
# NextOrderDate                        1.000000    NaN  ...             NaN
# Churn                                     NaN    NaN  ...             NaN
# TotalPurchase                        0.017523    NaN  ...             NaN
# TotalOrderAmountLast30Days                NaN    NaN  ...             NaN
# TotalOrderQuantityLast30Days              NaN    NaN  ...             NaN
# MaxOrderAmount                            NaN    NaN  ...             NaN
# Churn7Days                                NaN    NaN  ...             NaN
# Churn1Month                               NaN    NaN  ...             NaN
# TotalOrdersLast1Week                      NaN    NaN  ...             NaN
# TotalAmountLast1Week                      NaN    NaN  ...             NaN
# TimeSinceLastOrder                   0.005645    NaN  ...             NaN
# TotalOrdersLast1Month                     NaN    NaN  ...             NaN
# TotalAmountLast1Month                     NaN    NaN  ...             NaN
# MaxAmountLast30Days                       NaN    NaN  ...             NaN
# OverMaxAmountLast30Days                   NaN    NaN  ...             NaN
# MinAmountPriorToDate                      NaN    NaN  ...             NaN
# MeanAmountPriorToDate                     NaN    NaN  ...             NaN
# MinOrderAmount                            NaN    NaN  ...             NaN
# PrevMeanAmount                            NaN    NaN  ...             NaN
# CumulativeTime                       0.005645    NaN  ...             NaN
# PriorOrderCount                           NaN    NaN  ...             NaN
# AverageOrderDuration                      NaN    NaN  ...             NaN
# AverageOrderAmount                        NaN    NaN  ...             NaN
# TotalUniqueOrders                         NaN    NaN  ...             NaN
# DaysSinceFirstPurchase                    NaN    NaN  ...             NaN
# PreviousStdDevTotalOrderAmount       0.036353    NaN  ...             NaN
# OrderStdDeviation                    0.126973    NaN  ...             NaN
#
#                                 PrevMeanAmount  CumulativeTime  \
# InvoiceNo                                  NaN             NaN
# StockCode                                  NaN             NaN
# Description                                NaN             NaN
# Quantity                                   NaN       -0.002070
# InvoiceDate                                NaN             NaN
# UnitPrice                                  NaN       -0.001903
# CustomerID                                 NaN             NaN
# Country                                    NaN             NaN
# NextOrderDate                              NaN        0.005645
# Churn                                      NaN             NaN
# TotalPurchase                              NaN       -0.002813
# TotalOrderAmountLast30Days                 NaN             NaN
# TotalOrderQuantityLast30Days               NaN             NaN
# MaxOrderAmount                             NaN             NaN
# Churn7Days                                 NaN             NaN
# Churn1Month                                NaN             NaN
# TotalOrdersLast1Week                       NaN             NaN
# TotalAmountLast1Week                       NaN             NaN
# TimeSinceLastOrder                         NaN        1.000000
# TotalOrdersLast1Month                      NaN             NaN
# TotalAmountLast1Month                      NaN             NaN
# MaxAmountLast30Days                        NaN             NaN
# OverMaxAmountLast30Days                    NaN             NaN
# MinAmountPriorToDate                       NaN             NaN
# MeanAmountPriorToDate                      NaN             NaN
# MinOrderAmount                             NaN             NaN
# PrevMeanAmount                             NaN             NaN
# CumulativeTime                             NaN        1.000000
# PriorOrderCount                            NaN             NaN
# AverageOrderDuration                       NaN             NaN
# AverageOrderAmount                         NaN             NaN
# TotalUniqueOrders                          NaN             NaN
# DaysSinceFirstPurchase                     NaN             NaN
# PreviousStdDevTotalOrderAmount             NaN        0.181181
# OrderStdDeviation                          NaN        0.126973
#
#                                 PriorOrderCount  AverageOrderDuration  \
# InvoiceNo                                   NaN                   NaN
# StockCode                                   NaN                   NaN
# Description                                 NaN                   NaN
# Quantity                                    NaN                   NaN
# InvoiceDate                                 NaN                   NaN
# UnitPrice                                   NaN                   NaN
# CustomerID                                  NaN                   NaN
# Country                                     NaN                   NaN
# NextOrderDate                               NaN                   NaN
# Churn                                       NaN                   NaN
# TotalPurchase                               NaN                   NaN
# TotalOrderAmountLast30Days                  NaN                   NaN
# TotalOrderQuantityLast30Days                NaN                   NaN
# MaxOrderAmount                              NaN                   NaN
# Churn7Days                                  NaN                   NaN
# Churn1Month                                 NaN                   NaN
# TotalOrdersLast1Week                        NaN                   NaN
# TotalAmountLast1Week                        NaN                   NaN
# TimeSinceLastOrder                          NaN                   NaN
# TotalOrdersLast1Month                       NaN                   NaN
# TotalAmountLast1Month                       NaN                   NaN
# MaxAmountLast30Days                         NaN                   NaN
# OverMaxAmountLast30Days                     NaN                   NaN
# MinAmountPriorToDate                        NaN                   NaN
# MeanAmountPriorToDate                       NaN                   NaN
# MinOrderAmount                              NaN                   NaN
# PrevMeanAmount                              NaN                   NaN
# CumulativeTime                              NaN                   NaN
# PriorOrderCount                             NaN                   NaN
# AverageOrderDuration                        NaN                   NaN
# AverageOrderAmount                          NaN                   NaN
# TotalUniqueOrders                           NaN                   NaN
# DaysSinceFirstPurchase                      NaN                   NaN
# PreviousStdDevTotalOrderAmount              NaN                   NaN
# OrderStdDeviation                           NaN                   NaN
#
#                                 AverageOrderAmount  TotalUniqueOrders  \
# InvoiceNo                                      NaN                NaN
# StockCode                                      NaN                NaN
# Description                                    NaN                NaN
# Quantity                                       NaN                NaN
# InvoiceDate                                    NaN                NaN
# UnitPrice                                      NaN                NaN
# CustomerID                                     NaN                NaN
# Country                                        NaN                NaN
# NextOrderDate                                  NaN                NaN
# Churn                                          NaN                NaN
# TotalPurchase                                  NaN                NaN
# TotalOrderAmountLast30Days                     NaN                NaN
# TotalOrderQuantityLast30Days                   NaN                NaN
# MaxOrderAmount                                 NaN                NaN
# Churn7Days                                     NaN                NaN
# Churn1Month                                    NaN                NaN
# TotalOrdersLast1Week                           NaN                NaN
# TotalAmountLast1Week                           NaN                NaN
# TimeSinceLastOrder                             NaN                NaN
# TotalOrdersLast1Month                          NaN                NaN
# TotalAmountLast1Month                          NaN                NaN
# MaxAmountLast30Days                            NaN                NaN
# OverMaxAmountLast30Days                        NaN                NaN
# MinAmountPriorToDate                           NaN                NaN
# MeanAmountPriorToDate                          NaN                NaN
# MinOrderAmount                                 NaN                NaN
# PrevMeanAmount                                 NaN                NaN
# CumulativeTime                                 NaN                NaN
# PriorOrderCount                                NaN                NaN
# AverageOrderDuration                           NaN                NaN
# AverageOrderAmount                             NaN                NaN
# TotalUniqueOrders                              NaN                NaN
# DaysSinceFirstPurchase                         NaN                NaN
# PreviousStdDevTotalOrderAmount                 NaN                NaN
# OrderStdDeviation                              NaN                NaN
#
#                                 DaysSinceFirstPurchase  \
# InvoiceNo                                          NaN
# StockCode                                          NaN
# Description                                        NaN
# Quantity                                           NaN
# InvoiceDate                                        NaN
# UnitPrice                                          NaN
# CustomerID                                         NaN
# Country                                            NaN
# NextOrderDate                                      NaN
# Churn                                              NaN
# TotalPurchase                                      NaN
# TotalOrderAmountLast30Days                         NaN
# TotalOrderQuantityLast30Days                       NaN
# MaxOrderAmount                                     NaN
# Churn7Days                                         NaN
# Churn1Month                                        NaN
# TotalOrdersLast1Week                               NaN
# TotalAmountLast1Week                               NaN
# TimeSinceLastOrder                                 NaN
# TotalOrdersLast1Month                              NaN
# TotalAmountLast1Month                              NaN
# MaxAmountLast30Days                                NaN
# OverMaxAmountLast30Days                            NaN
# MinAmountPriorToDate                               NaN
# MeanAmountPriorToDate                              NaN
# MinOrderAmount                                     NaN
# PrevMeanAmount                                     NaN
# CumulativeTime                                     NaN
# PriorOrderCount                                    NaN
# AverageOrderDuration                               NaN
# AverageOrderAmount                                 NaN
# TotalUniqueOrders                                  NaN
# DaysSinceFirstPurchase                             NaN
# PreviousStdDevTotalOrderAmount                     NaN
# OrderStdDeviation                                  NaN
#
#                                 PreviousStdDevTotalOrderAmount  \
# InvoiceNo                                                  NaN
# StockCode                                                  NaN
# Description                                                NaN
# Quantity                                              0.007747
# InvoiceDate                                                NaN
# UnitPrice                                            -0.000539
# CustomerID                                                 NaN
# Country                                                    NaN
# NextOrderDate                                         0.036353
# Churn                                                      NaN
# TotalPurchase                                         0.005340
# TotalOrderAmountLast30Days                                 NaN
# TotalOrderQuantityLast30Days                               NaN
# MaxOrderAmount                                             NaN
# Churn7Days                                                 NaN
# Churn1Month                                                NaN
# TotalOrdersLast1Week                                       NaN
# TotalAmountLast1Week                                       NaN
# TimeSinceLastOrder                                    0.181181
# TotalOrdersLast1Month                                      NaN
# TotalAmountLast1Month                                      NaN
# MaxAmountLast30Days                                        NaN
# OverMaxAmountLast30Days                                    NaN
# MinAmountPriorToDate                                       NaN
# MeanAmountPriorToDate                                      NaN
# MinOrderAmount                                             NaN
# PrevMeanAmount                                             NaN
# CumulativeTime                                        0.181181
# PriorOrderCount                                            NaN
# AverageOrderDuration                                       NaN
# AverageOrderAmount                                         NaN
# TotalUniqueOrders                                          NaN
# DaysSinceFirstPurchase                                     NaN
# PreviousStdDevTotalOrderAmount                        1.000000
# OrderStdDeviation                                     0.023328
#
#                                 OrderStdDeviation
# InvoiceNo                                     NaN
# StockCode                                     NaN
# Description                                   NaN
# Quantity                                 0.008960
# InvoiceDate                                   NaN
# UnitPrice                               -0.000245
# CustomerID                                    NaN
# Country                                       NaN
# NextOrderDate                            0.126973
# Churn                                         NaN
# TotalPurchase                            0.006432
# TotalOrderAmountLast30Days                    NaN
# TotalOrderQuantityLast30Days                  NaN
# MaxOrderAmount                                NaN
# Churn7Days                                    NaN
# Churn1Month                                   NaN
# TotalOrdersLast1Week                          NaN
# TotalAmountLast1Week                          NaN
# TimeSinceLastOrder                       0.126973
# TotalOrdersLast1Month                         NaN
# TotalAmountLast1Month                         NaN
# MaxAmountLast30Days                           NaN
# OverMaxAmountLast30Days                       NaN
# MinAmountPriorToDate                          NaN
# MeanAmountPriorToDate                         NaN
# MinOrderAmount                                NaN
# PrevMeanAmount                                NaN
# CumulativeTime                           0.126973
# PriorOrderCount                               NaN
# AverageOrderDuration                          NaN
# AverageOrderAmount                            NaN
# TotalUniqueOrders                             NaN
# DaysSinceFirstPurchase                        NaN
# PreviousStdDevTotalOrderAmount           0.023328
# OrderStdDeviation                        1.000000
#
# [35 rows x 35 columns]

# %%
# Drop rows for 'TotalPurchase' and 'OrderStdDeviation'
df.dropna(subset=['TotalPurchase', 'OrderStdDeviation'], inplace=True)

# Drop the entire column 'PreviousStdDevTotalOrderAmount'
df.drop('PreviousStdDevTotalOrderAmount', axis=1, inplace=True)

# Drop rows with missing values in 'TimeSinceLastOrder' and 'CumulativeTime'
df.dropna(subset=['TimeSinceLastOrder', 'CumulativeTime'], inplace=True)

# Final check for missing values
print(df.isnull().sum())
# Out:
# InvoiceNo                          0
# StockCode                          0
# Description                        0
# Quantity                           0
# InvoiceDate                        0
# UnitPrice                          0
# CustomerID                         0
# Country                            0
# NextOrderDate                   4263
# Churn                              0
# TotalPurchase                      0
# TotalOrderAmountLast30Days         0
# TotalOrderQuantityLast30Days       0
# MaxOrderAmount                     0
# Churn7Days                         0
# Churn1Month                        0
# TotalOrdersLast1Week               0
# TotalAmountLast1Week               0
# TimeSinceLastOrder                 0
# TotalOrdersLast1Month              0
# TotalAmountLast1Month              0
# MaxAmountLast30Days                0
# OverMaxAmountLast30Days            0
# MinAmountPriorToDate               0
# MeanAmountPriorToDate              0
# MinOrderAmount                     0
# PrevMeanAmount                     0
# CumulativeTime                     0
# PriorOrderCount                    0
# AverageOrderDuration               0
# AverageOrderAmount                 0
# TotalUniqueOrders                  0
# DaysSinceFirstPurchase             0
# OrderStdDeviation                  0
# dtype: int64

# %% [markdown]
# This step aggregates the data to create a summary DataFrame, customer_churn_data, which is essential for training and evaluating churn prediction models.

# %%
# Aggregate the data to create the customer_churn_data DataFrame
customer_churn_data = df.groupby('CustomerID').agg({
    'Churn': 'max',
    'TotalOrderAmountLast30Days': 'mean',
    'TotalOrderQuantityLast30Days': 'mean',
    'MaxOrderAmount': 'max'  # Include the rolling max of MaxOrderAmount
}).reset_index()

# %%
# Display the aggregated customer_churn_data DataFrame
print(customer_churn_data)
# Out:
#       CustomerID  Churn  TotalOrderAmountLast30Days  \
# 0          12347   True                  664.593039
# 1          12348   True                  810.566667
# 2          12349   True                  458.361127
# 3          12350   True                  179.918750
# 4          12352   True                  396.370111
# ...          ...    ...                         ...
# 4280       18280   True                  108.438889
# 4281       18281   True                   42.105000
# 4282       18282   True                  102.066667
# 4283       18283   True                   78.895007
# 4284       18287   True                  606.822609
#
#       TotalOrderQuantityLast30Days  MaxOrderAmount
# 0                       366.198895           12.75
# 1                      1293.733333           40.00
# 2                       188.394366           39.95
# 3                       113.937500           40.00
# 4                       116.566667          183.75
# ...                            ...             ...
# 4280                     24.666667            9.95
# 4281                     39.500000           16.95
# 4282                     74.333333           12.75
# 4283                     53.328477           15.95
# 4284                    506.318841            8.50
#
# [4285 rows x 5 columns]

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 402135 entries, 3 to 406828
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   InvoiceNo                     402135 non-null  object
#  1   StockCode                     402135 non-null  object
#  2   Description                   402135 non-null  object
#  3   Quantity                      402135 non-null  float64
#  4   InvoiceDate                   402135 non-null  datetime64[ns]
#  5   UnitPrice                     402135 non-null  float64
#  6   CustomerID                    402135 non-null  int64
#  7   Country                       402135 non-null  object
#  8   NextOrderDate                 397872 non-null  datetime64[ns]
#  9   Churn                         402135 non-null  bool
#  10  TotalPurchase                 402135 non-null  float64
#  11  TotalOrderAmountLast30Days    402135 non-null  float64
#  12  TotalOrderQuantityLast30Days  402135 non-null  float64
#  13  MaxOrderAmount                402135 non-null  float64
#  14  Churn7Days                    402135 non-null  int64
#  15  Churn1Month                   402135 non-null  int64
#  16  TotalOrdersLast1Week          402135 non-null  float64
#  17  TotalAmountLast1Week          402135 non-null  float64
#  18  TimeSinceLastOrder            402135 non-null  float64
#  19  TotalOrdersLast1Month         402135 non-null  float64
#  20  TotalAmountLast1Month         402135 non-null  float64
#  21  MaxAmountLast30Days           402135 non-null  float64
#  22  OverMaxAmountLast30Days       402135 non-null  int64
#  23  MinAmountPriorToDate          402135 non-null  float64
#  24  MeanAmountPriorToDate         402135 non-null  float64
#  25  MinOrderAmount                402135 non-null  float64
#  26  PrevMeanAmount                402135 non-null  float64
#  27  CumulativeTime                402135 non-null  float64
#  28  PriorOrderCount               402135 non-null  int64
#  29  AverageOrderDuration          402135 non-null  float64
#  30  AverageOrderAmount            402135 non-null  float64
#  31  TotalUniqueOrders             402135 non-null  int64
#  32  DaysSinceFirstPurchase        402135 non-null  int64
#  33  OrderStdDeviation             402135 non-null  float64
# dtypes: bool(1), datetime64[ns](2), float64(20), int64(7), object(4)
# memory usage: 104.7+ MB
# None
#             Quantity      UnitPrice     CustomerID  TotalPurchase  \
# count  402135.000000  402135.000000  402135.000000  402135.000000
# mean       11.487806       2.964696   15287.710261      19.855833
# std        29.830575       4.323081    1713.328259      59.875954
# min      -720.000000       0.000000   12347.000000   -4522.500000
# 25%         2.000000       1.250000   13956.000000       4.200000
# 50%         5.000000       1.950000   15150.000000      10.500000
# 75%        12.000000       3.750000   16791.000000      19.500000
# max       756.000000     208.340000   18287.000000    4401.000000
#
#        TotalOrderAmountLast30Days  TotalOrderQuantityLast30Days  \
# count               402135.000000                 402135.000000
# mean                   510.687901                    294.698728
# std                   1072.419495                    515.791872
# min                  -6202.800000                  -2246.000000
# 25%                    151.210000                     83.000000
# 50%                    309.020000                    174.000000
# 75%                    546.120000                    327.000000
# max                  36131.810000                   9840.000000
#
#        MaxOrderAmount  Churn7Days  Churn1Month  TotalOrdersLast1Week  ...  \
# count   402135.000000    402135.0     402135.0         402135.000000  ...
# mean        21.713861         0.0          0.0             77.917468  ...
# std         30.192055         0.0          0.0            149.029474  ...
# min          0.120000         0.0          0.0          -2328.000000  ...
# 25%          8.950000         0.0          0.0             19.000000  ...
# 50%         12.750000         0.0          0.0             46.000000  ...
# 75%         16.950000         0.0          0.0             84.000000  ...
# max        208.340000         0.0          0.0           4340.000000  ...
#
#        MeanAmountPriorToDate  MinOrderAmount  PrevMeanAmount  CumulativeTime  \
# count          402135.000000   402135.000000   402135.000000   402135.000000
# mean              417.805949        0.272779       63.575901      131.814065
# std               893.231192        0.269487       34.763604      119.340142
# min              -833.220000        0.000000        0.100000        0.000000
# 25%               130.699960        0.120000       40.159293        0.053125
# 50%               237.716667        0.210000       63.801795      111.802083
# 75%               447.396294        0.390000       82.535962      232.213889
# max             22463.776471       21.950000      408.638333      373.096528
#
#        PriorOrderCount  AverageOrderDuration  AverageOrderAmount  \
# count    402135.000000          4.021350e+05       402135.000000
# mean        340.005113          1.450278e+00            2.971712
# std         875.762430          3.350435e-12            1.161483
# min           1.000000          1.450278e+00            0.143333
# 25%          30.000000          1.450278e+00            2.313374
# 50%          86.000000          1.450278e+00            2.772874
# 75%         228.000000          1.450278e+00            3.436909
# max        7982.000000          1.450278e+00           74.975000
#
#        TotalUniqueOrders  DaysSinceFirstPurchase  OrderStdDeviation
# count      402135.000000           402135.000000      402135.000000
# mean           23.414271              131.451386          13.540333
# std            45.698719              119.207355          19.894016
# min             1.000000                0.000000           0.000000
# 25%             4.000000                0.000000           5.218295
# 50%             8.000000              111.000000           7.957525
# 75%            19.000000              232.000000          13.332793
# max           248.000000              373.000000         773.649361
#
# [8 rows x 27 columns]

# %%
# Check the unique values in the 'Churn' column
print(df['Churn'].value_counts())

# Show some entries where 'Churn' is True
print(df[df['Churn'] == True].head())

# Show some entries where 'Churn' is False
print(df[df['Churn'] == False].head())

# Calculate the percentage of each category
churn_counts = df['Churn'].value_counts(normalize=True) * 100
print(churn_counts)
# Out:
# True     393651
# False      8484
# Name: Churn, dtype: int64
#   InvoiceNo StockCode                          Description  Quantity  \
# 3    537626     22375    AIRLINE BAG VINTAGE JET SET BROWN       4.0
# 4    537626     71477    COLOUR GLASS. STAR T-LIGHT HOLDER      12.0
# 5    537626     22492              MINI PAINT SET VINTAGE       36.0
# 6    537626     22771  CLEAR DRAWER KNOB ACRYLIC EDWARDIAN      12.0
# 7    537626     22772   PINK DRAWER KNOB ACRYLIC EDWARDIAN      12.0
#
#           InvoiceDate  UnitPrice  CustomerID  Country       NextOrderDate  \
# 3 2010-12-07 14:57:00       4.25       12347  Iceland 2010-12-07 14:57:00
# 4 2010-12-07 14:57:00       3.25       12347  Iceland 2010-12-07 14:57:00
# 5 2010-12-07 14:57:00       0.65       12347  Iceland 2010-12-07 14:57:00
# 6 2010-12-07 14:57:00       1.25       12347  Iceland 2010-12-07 14:57:00
# 7 2010-12-07 14:57:00       1.25       12347  Iceland 2010-12-07 14:57:00
#
#    Churn  ...  MeanAmountPriorToDate  MinOrderAmount  PrevMeanAmount  \
# 3   True  ...              33.700000            0.25        4.225000
# 4   True  ...              49.533333            0.25        6.016667
# 5   True  ...              63.300000            0.25        7.075000
# 6   True  ...              74.560000            0.25        7.960000
# 7   True  ...              84.566667            0.25        8.758333
#
#    CumulativeTime  PriorOrderCount  AverageOrderDuration  AverageOrderAmount  \
# 3             0.0                1              1.450278            2.644011
# 4             0.0                2              1.450278            2.644011
# 5             0.0                3              1.450278            2.644011
# 6             0.0                4              1.450278            2.644011
# 7             0.0                5              1.450278            2.644011
#
#    TotalUniqueOrders  DaysSinceFirstPurchase  OrderStdDeviation
# 3                  7                       0          18.856172
# 4                  7                       0          18.856172
# 5                  7                       0          18.856172
# 6                  7                       0          18.856172
# 7                  7                       0          18.856172
#
# [5 rows x 34 columns]
#     InvoiceNo StockCode                     Description  Quantity  \
# 182    581180     23506    MINI PLAYING CARDS SPACEBOY       20.0
# 183    581180     23508  MINI PLAYING CARDS DOLLY GIRL       20.0
# 213    568172     23078        ICE CREAM PEN LIP GLOSS       96.0
# 214    568172      POST                         POSTAGE       1.0
# 286    577609     48185              DOORMAT FAIRY CAKE       4.0
#
#             InvoiceDate  UnitPrice  CustomerID  Country       NextOrderDate  \
# 182 2011-12-07 15:52:00       0.42       12347  Iceland 2011-12-07 15:52:00
# 183 2011-12-07 15:52:00       0.42       12347  Iceland                 NaT
# 213 2011-09-25 13:13:00       1.25       12348  Finland 2011-09-25 13:13:00
# 214 2011-09-25 13:13:00      40.00       12348  Finland                 NaT
# 286 2011-11-21 09:51:00       8.25       12349    Italy 2011-11-21 09:51:00
#
#      Churn  ...  MeanAmountPriorToDate  MinOrderAmount  PrevMeanAmount  \
# 182  False  ...             660.918343            0.25       76.072044
# 183  False  ...             661.079890            0.25       75.944286
# 213  False  ...             753.298667            0.29       42.076667
# 214  False  ...             785.696774            0.29       46.466452
# 286  False  ...             452.203333            0.42      109.261389
#
#      CumulativeTime  PriorOrderCount  AverageOrderDuration  \
# 182      365.038194              180              1.450278
# 183      365.038194              181              1.450278
# 213      282.752778               29              1.450278
# 214      282.752778               30              1.450278
# 286        0.000000               71              1.450278
#
#      AverageOrderAmount  TotalUniqueOrders  DaysSinceFirstPurchase  \
# 182            2.644011                  7                     365
# 183            2.644011                  7                     365
# 213            5.764839                  4                     282
# 214            5.764839                  4                     282
# 286            4.237500                  1                       0
#
#      OrderStdDeviation
# 182          18.856172
# 183          18.856172
# 213          51.091990
# 214          51.091990
# 286           6.982856
#
# [5 rows x 34 columns]
# True     97.890261
# False     2.109739
# Name: Churn, dtype: float64

# %%
# Clipping outliers
df['TotalPurchase'] = df['TotalPurchase'].clip(lower=-500, upper=500)
df['TotalOrderQuantityLast30Days'] = df['TotalOrderQuantityLast30Days'].clip(lower=-1000, upper=2000)

# %% [markdown]
# **TotalPurchase:**
# Before clipping, the maximum value was 4522.5, and after clipping, it's capped at 500.
# The distribution has been corrected to prevent skewness caused by extreme positive values.
#
# **TotalOrderQuantityLast30Days:**
# Before clipping, the maximum value was 9840, and after clipping, it's capped at 2000.
# This prevents the skewness caused by very large positive values, which can distort the analysis.

# %%
# Verify the changes
print(df['TotalPurchase'].describe())
print(df['TotalOrderQuantityLast30Days'].describe())
# Out:
# count    402135.000000
# mean         19.057657
# std          40.194734
# min        -500.000000
# 25%           4.200000
# 50%          10.500000
# 75%          19.500000
# max         500.000000
# Name: TotalPurchase, dtype: float64
# count    402135.000000
# mean        270.294958
# std         335.783388
# min       -1000.000000
# 25%          83.000000
# 50%         174.000000
# 75%         327.000000
# max        2000.000000
# Name: TotalOrderQuantityLast30Days, dtype: float64

# %% [markdown]
# Data Distribution:
# The histograms of 'TotalPurchase' and 'TotalOrderQuantityLast30Days' show the distribution of these two important features. Understanding these distributions can provide insights into customer behavior and spending patterns.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of 'TotalPurchase' and 'TotalOrderQuantityLast30Days'
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(df['TotalPurchase'], bins=30, kde=True)
plt.title('Distribution of Total Purchase')

plt.subplot(1, 2, 2)
sns.histplot(df['TotalOrderQuantityLast30Days'], bins=30, kde=True)
plt.title('Distribution of Total Order Quantity (Last 30 Days)')

plt.show()

# %% [markdown]
# The countplot for 'Churn' helps you visualize the distribution of churned and non-churned customers. This is a critical aspect of your analysis, as you want to understand how many customers are churning.

# %%
plt.figure(figsize=(14, 6))

# TotalPurchase by Churn status
plt.subplot(1, 2, 1)
sns.histplot(df[df['Churn'] == True]['TotalPurchase'], label='Churned', kde=True)
sns.histplot(df[df['Churn'] == False]['TotalPurchase'], label='Non-Churned', kde=True)
plt.title('TotalPurchase Distribution by Churn Status')
plt.legend()

# TotalOrderQuantityLast30Days by Churn status
plt.subplot(1, 2, 2)
sns.histplot(df[df['Churn'] == True]['TotalOrderQuantityLast30Days'], label='Churned', kde=True)
sns.histplot(df[df['Churn'] == False]['TotalOrderQuantityLast30Days'], label='Non-Churned', kde=True)
plt.title('TotalOrderQuantityLast30Days Distribution by Churn Status')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Distribution of Churn
plt.figure(figsize=(8, 6))
sns.countplot(x='Churn', data=df)
plt.title("Distribution of Churn")
plt.show()

# %% [markdown]
# The heatmap of the correlation matrix shows how different features are correlated with each other. It's important for feature selection and understanding which features may be redundant or highly related to the target variable (churn).

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(14, 12))  
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', annot_kws={"size": 10}) 
plt.title('Correlation Heatmap', fontsize=16)  #increase font size to reduce overlapping 
plt.show()
print(correlation_matrix)
# Out:
#                               Quantity  UnitPrice  CustomerID     Churn  \
# Quantity                      1.000000  -0.110128   -0.031585 -0.011780
# UnitPrice                    -0.110128   1.000000   -0.028453 -0.049532
# CustomerID                   -0.031585  -0.028453    1.000000 -0.000334
# Churn                        -0.011780  -0.049532   -0.000334  1.000000
# TotalPurchase                 0.700182   0.116551   -0.046168 -0.021872
# TotalOrderAmountLast30Days    0.479037   0.032383   -0.028710  0.000555
# TotalOrderQuantityLast30Days  0.520747  -0.023725   -0.095862 -0.005968
# MaxOrderAmount                0.062597   0.113028   -0.052455  0.025398
# Churn7Days                         NaN        NaN         NaN       NaN
# Churn1Month                        NaN        NaN         NaN       NaN
# TotalOrdersLast1Week          0.720904  -0.037226   -0.045589 -0.015110
# TotalAmountLast1Week         -0.053067   0.467284   -0.048639 -0.029161
# TimeSinceLastOrder            0.027473   0.025818   -0.000118 -0.011872
# TotalOrdersLast1Month         0.574627  -0.016496   -0.052870 -0.001163
# TotalAmountLast1Month        -0.027274   0.241101   -0.063447  0.005689
# MaxAmountLast30Days           0.440502   0.027585   -0.023780  0.004484
# OverMaxAmountLast30Days            NaN        NaN         NaN       NaN
# MinAmountPriorToDate          0.029300  -0.015794    0.040368 -0.016400
# MeanAmountPriorToDate         0.411520   0.021706   -0.026821  0.009456
# MinOrderAmount                0.016006   0.100048    0.000063 -0.154463
# PrevMeanAmount               -0.017721   0.101516   -0.051880  0.037896
# CumulativeTime                0.048153  -0.021127    0.020774 -0.004661
# PriorOrderCount              -0.024099  -0.001843    0.039669  0.041331
# AverageOrderDuration               NaN        NaN         NaN       NaN
# AverageOrderAmount           -0.020754   0.269514   -0.104928 -0.046743
# TotalUniqueOrders             0.036841   0.008203   -0.033314  0.058674
# DaysSinceFirstPurchase        0.048128  -0.021133    0.020758 -0.004692
# OrderStdDeviation             0.525388  -0.001768   -0.038089 -0.003172
#
#                               TotalPurchase  TotalOrderAmountLast30Days  \
# Quantity                           0.700182                    0.479037
# UnitPrice                          0.116551                    0.032383
# CustomerID                        -0.046168                   -0.028710
# Churn                             -0.021872                    0.000555
# TotalPurchase                      1.000000                    0.596173
# TotalOrderAmountLast30Days         0.596173                    1.000000
# TotalOrderQuantityLast30Days       0.534362                    0.708824
# MaxOrderAmount                     0.107819                    0.204169
# Churn7Days                              NaN                         NaN
# Churn1Month                             NaN                         NaN
# TotalOrdersLast1Week               0.641536                    0.682482
# TotalAmountLast1Week               0.084061                    0.079824
# TimeSinceLastOrder                 0.034977                    0.006380
# TotalOrdersLast1Month              0.576518                    0.849640
# TotalAmountLast1Month              0.063337                    0.177216
# MaxAmountLast30Days                0.550227                    0.933787
# OverMaxAmountLast30Days                 NaN                         NaN
# MinAmountPriorToDate               0.047526                    0.092575
# MeanAmountPriorToDate              0.529002                    0.859396
# MinOrderAmount                     0.106257                    0.056239
# PrevMeanAmount                     0.047321                    0.183984
# CumulativeTime                     0.058965                    0.142336
# PriorOrderCount                   -0.030361                   -0.009144
# AverageOrderDuration                    NaN                         NaN
# AverageOrderAmount                 0.093885                    0.092693
# TotalUniqueOrders                  0.041681                    0.083809
# DaysSinceFirstPurchase             0.058936                    0.142241
# OrderStdDeviation                  0.525963                    0.649052
#
#                               TotalOrderQuantityLast30Days  MaxOrderAmount  \
# Quantity                                          0.520747        0.062597
# UnitPrice                                        -0.023725        0.113028
# CustomerID                                       -0.095862       -0.052455
# Churn                                            -0.005968        0.025398
# TotalPurchase                                     0.534362        0.107819
# TotalOrderAmountLast30Days                        0.708824        0.204169
# TotalOrderQuantityLast30Days                      1.000000        0.134268
# MaxOrderAmount                                    0.134268        1.000000
# Churn7Days                                             NaN             NaN
# Churn1Month                                            NaN             NaN
# TotalOrdersLast1Week                              0.739587        0.094020
# TotalAmountLast1Week                             -0.031223        0.235005
# TimeSinceLastOrder                                0.008476       -0.018596
# TotalOrdersLast1Month                             0.895991        0.149736
# TotalAmountLast1Month                             0.049838        0.409146
# MaxAmountLast30Days                               0.675306        0.224209
# OverMaxAmountLast30Days                                NaN             NaN
# MinAmountPriorToDate                              0.024484       -0.350259
# MeanAmountPriorToDate                             0.656164        0.251031
# MinOrderAmount                                   -0.066500       -0.069756
# PrevMeanAmount                                    0.101804        0.566890
# CumulativeTime                                    0.192594        0.266299
# PriorOrderCount                                  -0.011065        0.434958
# AverageOrderDuration                                   NaN             NaN
# AverageOrderAmount                               -0.051180        0.328165
# TotalUniqueOrders                                 0.107804        0.391816
# DaysSinceFirstPurchase                            0.192443        0.266201
# OrderStdDeviation                                 0.741034        0.124893
#
#                               Churn7Days  Churn1Month  ...  \
# Quantity                             NaN          NaN  ...
# UnitPrice                            NaN          NaN  ...
# CustomerID                           NaN          NaN  ...
# Churn                                NaN          NaN  ...
# TotalPurchase                        NaN          NaN  ...
# TotalOrderAmountLast30Days           NaN          NaN  ...
# TotalOrderQuantityLast30Days         NaN          NaN  ...
# MaxOrderAmount                       NaN          NaN  ...
# Churn7Days                           NaN          NaN  ...
# Churn1Month                          NaN          NaN  ...
# TotalOrdersLast1Week                 NaN          NaN  ...
# TotalAmountLast1Week                 NaN          NaN  ...
# TimeSinceLastOrder                   NaN          NaN  ...
# TotalOrdersLast1Month                NaN          NaN  ...
# TotalAmountLast1Month                NaN          NaN  ...
# MaxAmountLast30Days                  NaN          NaN  ...
# OverMaxAmountLast30Days              NaN          NaN  ...
# MinAmountPriorToDate                 NaN          NaN  ...
# MeanAmountPriorToDate                NaN          NaN  ...
# MinOrderAmount                       NaN          NaN  ...
# PrevMeanAmount                       NaN          NaN  ...
# CumulativeTime                       NaN          NaN  ...
# PriorOrderCount                      NaN          NaN  ...
# AverageOrderDuration                 NaN          NaN  ...
# AverageOrderAmount                   NaN          NaN  ...
# TotalUniqueOrders                    NaN          NaN  ...
# DaysSinceFirstPurchase               NaN          NaN  ...
# OrderStdDeviation                    NaN          NaN  ...
#
#                               MeanAmountPriorToDate  MinOrderAmount  \
# Quantity                                   0.411520        0.016006
# UnitPrice                                  0.021706        0.100048
# CustomerID                                -0.026821        0.000063
# Churn                                      0.009456       -0.154463
# TotalPurchase                              0.529002        0.106257
# TotalOrderAmountLast30Days                 0.859396        0.056239
# TotalOrderQuantityLast30Days               0.656164       -0.066500
# MaxOrderAmount                             0.251031       -0.069756
# Churn7Days                                      NaN             NaN
# Churn1Month                                     NaN             NaN
# TotalOrdersLast1Week                       0.574464        0.007699
# TotalAmountLast1Week                       0.058524        0.132505
# TimeSinceLastOrder                        -0.002911        0.053819
# TotalOrdersLast1Month                      0.737424       -0.035018
# TotalAmountLast1Month                      0.161217       -0.006761
# MaxAmountLast30Days                        0.921653        0.046956
# OverMaxAmountLast30Days                         NaN             NaN
# MinAmountPriorToDate                       0.085829        0.125701
# MeanAmountPriorToDate                      1.000000        0.033461
# MinOrderAmount                             0.033461        1.000000
# PrevMeanAmount                             0.234110       -0.118509
# CumulativeTime                             0.184867       -0.176566
# PriorOrderCount                            0.018413       -0.198680
# AverageOrderDuration                            NaN             NaN
# AverageOrderAmount                         0.086710        0.372932
# TotalUniqueOrders                          0.120690       -0.258935
# DaysSinceFirstPurchase                     0.184755       -0.176436
# OrderStdDeviation                          0.671162       -0.029595
#
#                               PrevMeanAmount  CumulativeTime  PriorOrderCount  \
# Quantity                           -0.017721        0.048153        -0.024099
# UnitPrice                           0.101516       -0.021127        -0.001843
# CustomerID                         -0.051880        0.020774         0.039669
# Churn                               0.037896       -0.004661         0.041331
# TotalPurchase                       0.047321        0.058965        -0.030361
# TotalOrderAmountLast30Days          0.183984        0.142336        -0.009144
# TotalOrderQuantityLast30Days        0.101804        0.192594        -0.011065
# MaxOrderAmount                      0.566890        0.266299         0.434958
# Churn7Days                               NaN             NaN              NaN
# Churn1Month                              NaN             NaN              NaN
# TotalOrdersLast1Week               -0.003818        0.079069        -0.027701
# TotalAmountLast1Week                0.282817        0.007496         0.010792
# TimeSinceLastOrder                 -0.030972        0.053115        -0.035340
# TotalOrdersLast1Month               0.086795        0.158337        -0.005734
# TotalAmountLast1Month               0.736630        0.225803         0.099081
# MaxAmountLast30Days                 0.205167        0.157918         0.003599
# OverMaxAmountLast30Days                  NaN             NaN              NaN
# MinAmountPriorToDate               -0.163296       -0.171749        -0.453591
# MeanAmountPriorToDate               0.234110        0.184867         0.018413
# MinOrderAmount                     -0.118509       -0.176566        -0.198680
# PrevMeanAmount                      1.000000        0.452412         0.267895
# CumulativeTime                      0.452412        1.000000         0.357334
# PriorOrderCount                     0.267895        0.357334         1.000000
# AverageOrderDuration                     NaN             NaN              NaN
# AverageOrderAmount                  0.457431       -0.024184         0.005814
# TotalUniqueOrders                   0.309907        0.281219         0.725541
# DaysSinceFirstPurchase              0.452003        0.999995         0.357301
# OrderStdDeviation                   0.014637        0.103687         0.021479
#
#                               AverageOrderDuration  AverageOrderAmount  \
# Quantity                                       NaN           -0.020754
# UnitPrice                                      NaN            0.269514
# CustomerID                                     NaN           -0.104928
# Churn                                          NaN           -0.046743
# TotalPurchase                                  NaN            0.093885
# TotalOrderAmountLast30Days                     NaN            0.092693
# TotalOrderQuantityLast30Days                   NaN           -0.051180
# MaxOrderAmount                                 NaN            0.328165
# Churn7Days                                     NaN                 NaN
# Churn1Month                                    NaN                 NaN
# TotalOrdersLast1Week                           NaN           -0.029353
# TotalAmountLast1Week                           NaN            0.465773
# TimeSinceLastOrder                             NaN            0.024680
# TotalOrdersLast1Month                          NaN           -0.034372
# TotalAmountLast1Month                          NaN            0.499301
# MaxAmountLast30Days                            NaN            0.090553
# OverMaxAmountLast30Days                        NaN                 NaN
# MinAmountPriorToDate                           NaN           -0.067975
# MeanAmountPriorToDate                          NaN            0.086710
# MinOrderAmount                                 NaN            0.372932
# PrevMeanAmount                                 NaN            0.457431
# CumulativeTime                                 NaN           -0.024184
# PriorOrderCount                                NaN            0.005814
# AverageOrderDuration                           NaN                 NaN
# AverageOrderAmount                             NaN            1.000000
# TotalUniqueOrders                              NaN            0.028009
# DaysSinceFirstPurchase                         NaN           -0.024179
# OrderStdDeviation                              NaN           -0.013339
#
#                               TotalUniqueOrders  DaysSinceFirstPurchase  \
# Quantity                               0.036841                0.048128
# UnitPrice                              0.008203               -0.021133
# CustomerID                            -0.033314                0.020758
# Churn                                  0.058674               -0.004692
# TotalPurchase                          0.041681                0.058936
# TotalOrderAmountLast30Days             0.083809                0.142241
# TotalOrderQuantityLast30Days           0.107804                0.192443
# MaxOrderAmount                         0.391816                0.266201
# Churn7Days                                  NaN                     NaN
# Churn1Month                                 NaN                     NaN
# TotalOrdersLast1Week                   0.056190                0.079016
# TotalAmountLast1Week                   0.032987                0.007425
# TimeSinceLastOrder                    -0.036168                0.053040
# TotalOrdersLast1Month                  0.095076                0.158228
# TotalAmountLast1Month                  0.133878                0.225458
# MaxAmountLast30Days                    0.102805                0.157826
# OverMaxAmountLast30Days                     NaN                     NaN
# MinAmountPriorToDate                  -0.518972               -0.171732
# MeanAmountPriorToDate                  0.120690                0.184755
# MinOrderAmount                        -0.258935               -0.176436
# PrevMeanAmount                         0.309907                0.452003
# CumulativeTime                         0.281219                0.999995
# PriorOrderCount                        0.725541                0.357301
# AverageOrderDuration                        NaN                     NaN
# AverageOrderAmount                     0.028009               -0.024179
# TotalUniqueOrders                      1.000000                0.281027
# DaysSinceFirstPurchase                 0.281027                1.000000
# OrderStdDeviation                      0.168974                0.103622
#
#                               OrderStdDeviation
# Quantity                               0.525388
# UnitPrice                             -0.001768
# CustomerID                            -0.038089
# Churn                                 -0.003172
# TotalPurchase                          0.525963
# TotalOrderAmountLast30Days             0.649052
# TotalOrderQuantityLast30Days           0.741034
# MaxOrderAmount                         0.124893
# Churn7Days                                  NaN
# Churn1Month                                 NaN
# TotalOrdersLast1Week                   0.692054
# TotalAmountLast1Week                  -0.002813
# TimeSinceLastOrder                     0.019252
# TotalOrdersLast1Month                  0.764666
# TotalAmountLast1Month                  0.004870
# MaxAmountLast30Days                    0.673282
# OverMaxAmountLast30Days                     NaN
# MinAmountPriorToDate                  -0.023745
# MeanAmountPriorToDate                  0.671162
# MinOrderAmount                        -0.029595
# PrevMeanAmount                         0.014637
# CumulativeTime                         0.103687
# PriorOrderCount                        0.021479
# AverageOrderDuration                        NaN
# AverageOrderAmount                    -0.013339
# TotalUniqueOrders                      0.168974
# DaysSinceFirstPurchase                 0.103622
# OrderStdDeviation                      1.000000
#
# [28 rows x 28 columns]

# %%
# Convert InvoiceDate to date only
df['Date'] = df['InvoiceDate'].dt.date

# Aggregate TotalPurchase and TotalOrderQuantityLast30Days by date
daily_totals = df.groupby('Date').agg({
    'TotalPurchase': 'sum',
    'TotalOrderQuantityLast30Days': 'sum'
}).reset_index()

# Plot time series
plt.figure(figsize=(14, 6))
plt.plot(daily_totals['Date'], daily_totals['TotalPurchase'], label='Total Purchase')
plt.plot(daily_totals['Date'], daily_totals['TotalOrderQuantityLast30Days'], label='Total Order Quantity Last 30 Days')
plt.title('Daily Trends')
plt.xlabel('Date')
plt.ylabel('Amount/Quantity')
plt.legend()
plt.show()

# %% [markdown]
# Time-Based Analysis:
#
# The histogram of 'InvoiceDate' provides an overview of the distribution of invoice dates. This is essential for understanding the temporal aspect of your data.
# The line plot of the churn rate over time (monthly) shows how churn is changing over time. This is valuable for identifying trends and seasonality in customer churn.

# %%
# Time-based analysis: Churn over time
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
df['InvoiceDate'].hist(bins=50)
plt.title('Invoice Date Distribution')

plt.subplot(1, 2, 2)
df.groupby(df['InvoiceDate'].dt.to_period('M'))['Churn'].mean().plot(kind='line')
plt.title('Churn Rate Over Time (Monthly)')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# Customer Distribution by Country: This countplot shows the distribution of customers by country. It's essential for understanding the geographic distribution of your customer base and potential variations in behavior across different countries.

# %%
# Customer distribution by country
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Country')
plt.title('Customer Distribution by Country')
plt.xticks(rotation=90)
plt.show()

# %%
# Perform segmentation without altering the dataset
segmentation_data = df.copy()

# Define segmentation criteria and create segments
segmentation_data['Segment'] = pd.cut(segmentation_data['TotalPurchase'], bins=[-np.inf, 100, 500, np.inf], labels=['Low', 'Medium', 'High'])

# Analyze segment distribution
segment_distribution = segmentation_data['Segment'].value_counts(normalize=True) * 100
print("Segment Distribution:\n", segment_distribution)

# Visualize segment distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='Segment', data=segmentation_data, order=['Low', 'Medium', 'High'])
plt.title("Customer Segmentation by Total Purchase")
plt.xlabel("Segment")
plt.ylabel("Count")
plt.show()
# Out:
# Segment Distribution:
#  Low       97.225559
# Medium     2.774441
# High       0.000000
# Name: Segment, dtype: float64

# %% [markdown]
# # Model Training and Validation

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Data Splitting**
#
# This cutoff date is used to divide the data into a development sample (dev_sample) and an out-of-time sample (out_of_time_sample). The dev_sample includes all data before the cutoff date, which will be further split into training and validation sets.

# %%
# Find the latest date
latest_date = df['InvoiceDate'].max()
print("Cutoff Date:", latest_date)
# Out:
# Cutoff Date: 2011-12-09 12:50:00

# %%
# Set the cutoff date
cutoff_date = '2011-12-09 12:50:00'

# %%
# Step 1: Split data into dev_sample and out_of_time_sample
dev_sample = df[df['InvoiceDate'] < cutoff_date]
out_of_time_sample = df[df['InvoiceDate'] >= cutoff_date]

# %% [markdown]
# **Train-Validation Split**

# %%
# Split dev_sample into train_sample and validation_sample
train_sample, validation_sample = train_test_split(dev_sample, test_size=0.3, random_state=42)

# %%
# 'Churn' is your binary target variable (Y)
target_variable = 'Churn'

# %% [markdown]
# **Feature Selection**

# %%
# Build a model using xgboost
feature_columns = [
    'TotalOrdersLast1Week',
    'TotalAmountLast1Week',
    'TimeSinceLastOrder',
    'TotalOrdersLast1Month',
    'TotalAmountLast1Month',
    'MaxOrderAmount',
    'MinOrderAmount',
    'AverageOrderAmount',
    'TotalUniqueOrders',
    'AverageOrderDuration',
    'DaysSinceFirstPurchase',
    'OrderStdDeviation'
]

# %%
X_train = train_sample[feature_columns]
y_train = train_sample[target_variable]

X_validation = validation_sample[feature_columns]
y_validation = validation_sample[target_variable]

# %% [markdown]
# **Model Training** initialize XGBoost classifier model and train it using the training data (X_train, y_train)

# %%
model = xgb.XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %% [markdown]
# **Model Evaluation**

# %%
#Evaluate the model's performance on the validation set use predict_proba insead of predict

y_proba = model.predict_proba(X_validation)[:, 1]

# %%
# Vary the threshold from 0 to 1 with a step of 0.05
thresholds = [i * 0.05 for i in range(21)]
f1_scores = []

# %%
from sklearn.metrics import f1_score

for threshold in thresholds:
    # Apply the threshold to classify samples as True or False
    y_pred = (y_proba >= threshold).astype(int)

    # Calculate the F1-score for this threshold
    f1 = f1_score(y_validation, y_pred)
    f1_scores.append(f1)

# %%
best_threshold = thresholds[f1_scores.index(max(f1_scores))]
best_f1_score = max(f1_scores)

# %%
# best threshold to classify the samples
y_pred = (y_proba >= best_threshold).astype(int)

# %%
print("Best Threshold:", best_threshold)
print("Best F1-Score:", best_f1_score)
# Out:
# Best Threshold: 0.30000000000000004
# Best F1-Score: 0.9895290809977333

# %%
# Calculate accuracy and other classification metrics
accuracy = accuracy_score(y_validation, y_pred)
conf_matrix = confusion_matrix(y_validation, y_pred)
classification_rep = classification_report(y_validation, y_pred)

print(f"Validation Accuracy: {accuracy}")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(classification_rep)
# Out:
# Validation Accuracy: 0.9792847906097683
# Confusion Matrix:
# [[    56   2474]
#  [    25 118081]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.69      0.02      0.04      2530
#         True       0.98      1.00      0.99    118106
#
#     accuracy                           0.98    120636
#    macro avg       0.84      0.51      0.52    120636
# weighted avg       0.97      0.98      0.97    120636

# %%
print(train_sample.columns)
print(df.head())
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'NextOrderDate', 'Churn',
#        'TotalPurchase', 'TotalOrderAmountLast30Days',
#        'TotalOrderQuantityLast30Days', 'MaxOrderAmount', 'Churn7Days',
#        'Churn1Month', 'TotalOrdersLast1Week', 'TotalAmountLast1Week',
#        'TimeSinceLastOrder', 'TotalOrdersLast1Month', 'TotalAmountLast1Month',
#        'MaxAmountLast30Days', 'OverMaxAmountLast30Days',
#        'MinAmountPriorToDate', 'MeanAmountPriorToDate', 'MinOrderAmount',
#        'PrevMeanAmount', 'CumulativeTime', 'PriorOrderCount',
#        'AverageOrderDuration', 'AverageOrderAmount', 'TotalUniqueOrders',
#        'DaysSinceFirstPurchase', 'OrderStdDeviation', 'Date'],
#       dtype='object')
#   InvoiceNo StockCode                          Description  Quantity  \
# 3    537626     22375    AIRLINE BAG VINTAGE JET SET BROWN       4.0
# 4    537626     71477    COLOUR GLASS. STAR T-LIGHT HOLDER      12.0
# 5    537626     22492              MINI PAINT SET VINTAGE       36.0
# 6    537626     22771  CLEAR DRAWER KNOB ACRYLIC EDWARDIAN      12.0
# 7    537626     22772   PINK DRAWER KNOB ACRYLIC EDWARDIAN      12.0
#
#           InvoiceDate  UnitPrice  CustomerID  Country       NextOrderDate  \
# 3 2010-12-07 14:57:00       4.25       12347  Iceland 2010-12-07 14:57:00
# 4 2010-12-07 14:57:00       3.25       12347  Iceland 2010-12-07 14:57:00
# 5 2010-12-07 14:57:00       0.65       12347  Iceland 2010-12-07 14:57:00
# 6 2010-12-07 14:57:00       1.25       12347  Iceland 2010-12-07 14:57:00
# 7 2010-12-07 14:57:00       1.25       12347  Iceland 2010-12-07 14:57:00
#
#    Churn  ...  MinOrderAmount  PrevMeanAmount  CumulativeTime  \
# 3   True  ...            0.25        4.225000             0.0
# 4   True  ...            0.25        6.016667             0.0
# 5   True  ...            0.25        7.075000             0.0
# 6   True  ...            0.25        7.960000             0.0
# 7   True  ...            0.25        8.758333             0.0
#
#    PriorOrderCount  AverageOrderDuration  AverageOrderAmount  \
# 3                1              1.450278            2.644011
# 4                2              1.450278            2.644011
# 5                3              1.450278            2.644011
# 6                4              1.450278            2.644011
# 7                5              1.450278            2.644011
#
#    TotalUniqueOrders  DaysSinceFirstPurchase  OrderStdDeviation        Date
# 3                  7                       0          18.856172  2010-12-07
# 4                  7                       0          18.856172  2010-12-07
# 5                  7                       0          18.856172  2010-12-07
# 6                  7                       0          18.856172  2010-12-07
# 7                  7                       0          18.856172  2010-12-07
#
# [5 rows x 35 columns]

# %% [markdown]
# # Model Hyper Parameter Tuning with RUS
# The Random UnderSampling method was used to balance the number of churned and non-churned customers in the dataset. In the original dataset, there might have been a significant imbalance between these two classes, which can lead to a biased model that performs well on the majority class but poorly on the minority class. By balancing the classes, RUS helps in improving the model's ability to generalize and correctly predict both churned and non-churned customers.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# One-hot encode categorical column 'Country'
X = pd.get_dummies(df, columns=['Country'], drop_first=True)

# %%
df['Date'] = pd.to_datetime(df['Date']) #need to drop after

# %%
# Feature engineering for datetime columns
df['InvoiceYear'] = df['InvoiceDate'].dt.year
df['InvoiceMonth'] = df['InvoiceDate'].dt.month
df['InvoiceDay'] = df['InvoiceDate'].dt.day
df['InvoiceHour'] = df['InvoiceDate'].dt.hour
df['NextOrderYear'] = df['NextOrderDate'].dt.year
df['NextOrderMonth'] = df['NextOrderDate'].dt.month
df['NextOrderDay'] = df['NextOrderDate'].dt.day
df['NextOrderHour'] = df['NextOrderDate'].dt.hour

# %%
# Define features (X) and target (y)
X = df.drop(['Churn', 'Churn7Days', 'Churn1Month', 'InvoiceDate', 'NextOrderDate', 'InvoiceNo', 'StockCode', 'Description', 'CustomerID', 'Date'], axis=1)
y = df['Churn']

# %%
# Ensure there are no 'object' types left and convert to 'category' where appropriate
for col in X.select_dtypes(include='object').columns:
    X[col] = X[col].astype('category')
    
print(X.dtypes)
# Out:
# Quantity                         float64
# UnitPrice                        float64
# Country                         category
# TotalPurchase                    float64
# TotalOrderAmountLast30Days       float64
# TotalOrderQuantityLast30Days     float64
# MaxOrderAmount                   float64
# TotalOrdersLast1Week             float64
# TotalAmountLast1Week             float64
# TimeSinceLastOrder               float64
# TotalOrdersLast1Month            float64
# TotalAmountLast1Month            float64
# MaxAmountLast30Days              float64
# OverMaxAmountLast30Days            int64
# MinAmountPriorToDate             float64
# MeanAmountPriorToDate            float64
# MinOrderAmount                   float64
# PrevMeanAmount                   float64
# CumulativeTime                   float64
# PriorOrderCount                    int64
# AverageOrderDuration             float64
# AverageOrderAmount               float64
# TotalUniqueOrders                  int64
# DaysSinceFirstPurchase             int64
# OrderStdDeviation                float64
# InvoiceYear                        int64
# InvoiceMonth                       int64
# InvoiceDay                         int64
# InvoiceHour                        int64
# NextOrderYear                    float64
# NextOrderMonth                   float64
# NextOrderDay                     float64
# NextOrderHour                    float64
# dtype: object

# %%
# Perform Random UnderSampling
rus = RandomUnderSampler(random_state=42)
X_rus, y_rus = rus.fit_resample(X, y)

# %%
# Train-Test Split for RUS dataset
X_train_rus, X_test_rus, y_train_rus, y_test_rus = train_test_split(X_rus, y_rus, test_size=0.2, random_state=42)

# %%
# Define the hyperparameter grid for tuning
param_grid = {
    'max_depth': [3, 4, 5],
    'learning_rate': [0.05, 0.1],
    'n_estimators': [100, 200],
    'gamma': [0.1, 0.2],
    'subsample': [0.7, 0.8],
    'colsample_bytree': [0.7, 0.8],
    'min_child_weight': [1, 2]
}

# %%
# Initialize the XGBoost classifier with categorical data support
xgb_classifier = XGBClassifier(
    objective='binary:logistic',
    enable_categorical=True,
    tree_method='hist'
)

# %%
# Create the GridSearchCV object
grid_search = GridSearchCV(
    estimator=xgb_classifier,
    param_grid=param_grid,
    scoring='roc_auc',
    cv=5,
    n_jobs=-1,
    verbose=1
)

# %%
# Fit the GridSearchCV object
grid_search.fit(X_train_rus, y_train_rus)
# Print the best parameters found by GridSearchCV
print("Best Parameters:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# Best Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'subsample': 0.8}

# %%
# Evaluate the best model
best_model = grid_search.best_estimator_

# Perform early stopping with validation data
eval_set = [(X_test_rus, y_test_rus)]
best_model.fit(
    X_train_rus, y_train_rus,
    early_stopping_rounds=10,
    eval_metric="logloss",
    eval_set=eval_set,
    verbose=True
)
# Out:
# [0]	validation_0-logloss:0.65172
# [1]	validation_0-logloss:0.61203
# [2]	validation_0-logloss:0.58396
# [3]	validation_0-logloss:0.55524
# [4]	validation_0-logloss:0.53008
# [5]	validation_0-logloss:0.50912
# [6]	validation_0-logloss:0.49283
# [7]	validation_0-logloss:0.47563
# [8]	validation_0-logloss:0.46104
# [9]	validation_0-logloss:0.44847
# [10]	validation_0-logloss:0.43930
# [11]	validation_0-logloss:0.42887
# [12]	validation_0-logloss:0.41865
# [13]	validation_0-logloss:0.41045
# [14]	validation_0-logloss:0.40228
# [15]	validation_0-logloss:0.39559
# [16]	validation_0-logloss:0.38937
# [17]	validation_0-logloss:0.38435
# [18]	validation_0-logloss:0.37833
# [19]	validation_0-logloss:0.37353
# [20]	validation_0-logloss:0.36839
# [21]	validation_0-logloss:0.36474
# [22]	validation_0-logloss:0.36060
# [23]	validation_0-logloss:0.35755
# [24]	validation_0-logloss:0.35416
# [25]	validation_0-logloss:0.34804
# [26]	validation_0-logloss:0.34411
# [27]	validation_0-logloss:0.34169
# [28]	validation_0-logloss:0.33884
# [29]	validation_0-logloss:0.33655
# [30]	validation_0-logloss:0.33415
# [31]	validation_0-logloss:0.33120
# [32]	validation_0-logloss:0.32962
# [33]	validation_0-logloss:0.32716
# [34]	validation_0-logloss:0.32519
# [35]	validation_0-logloss:0.32390
# [36]	validation_0-logloss:0.31977
# [37]	validation_0-logloss:0.31853
# [38]	validation_0-logloss:0.31729
# [39]	validation_0-logloss:0.31589
# [40]	validation_0-logloss:0.31489
# [41]	validation_0-logloss:0.31311
# [42]	validation_0-logloss:0.30961
# [43]	validation_0-logloss:0.30536
# [44]	validation_0-logloss:0.30446
# [45]	validation_0-logloss:0.30330
# [46]	validation_0-logloss:0.30227
# [47]	validation_0-logloss:0.30158
# [48]	validation_0-logloss:0.30043
# [49]	validation_0-logloss:0.29964
# [50]	validation_0-logloss:0.29828
# [51]	validation_0-logloss:0.29785
# [52]	validation_0-logloss:0.29489
# [53]	validation_0-logloss:0.29447
# [54]	validation_0-logloss:0.29313
# [55]	validation_0-logloss:0.29249
# [56]	validation_0-logloss:0.29207
# [57]	validation_0-logloss:0.28994
# [58]	validation_0-logloss:0.28951
# [59]	validation_0-logloss:0.28886
# [60]	validation_0-logloss:0.28858
# [61]	validation_0-logloss:0.28799
# [62]	validation_0-logloss:0.28754
# [63]	validation_0-logloss:0.28698
# [64]	validation_0-logloss:0.28670
# [65]	validation_0-logloss:0.28560
# [66]	validation_0-logloss:0.28537
# [67]	validation_0-logloss:0.28493
# [68]	validation_0-logloss:0.28388
# [69]	validation_0-logloss:0.28253
# [70]	validation_0-logloss:0.28243
# [71]	validation_0-logloss:0.28193
# [72]	validation_0-logloss:0.28125
# [73]	validation_0-logloss:0.28029
# [74]	validation_0-logloss:0.28016
# [75]	validation_0-logloss:0.27947
# [76]	validation_0-logloss:0.27932
# [77]	validation_0-logloss:0.27927
# [78]	validation_0-logloss:0.27923
# [79]	validation_0-logloss:0.27918
# [80]	validation_0-logloss:0.27883
# [81]	validation_0-logloss:0.27858
# [82]	validation_0-logloss:0.27840
# [83]	validation_0-logloss:0.27765
# [84]	validation_0-logloss:0.27725
# [85]	validation_0-logloss:0.27677
# [86]	validation_0-logloss:0.27605
# [87]	validation_0-logloss:0.27595
# [88]	validation_0-logloss:0.27562
# [89]	validation_0-logloss:0.27544
# [90]	validation_0-logloss:0.27540
# [91]	validation_0-logloss:0.27434
# [92]	validation_0-logloss:0.27422
# [93]	validation_0-logloss:0.27389
# [94]	validation_0-logloss:0.27348
# [95]	validation_0-logloss:0.27322
# [96]	validation_0-logloss:0.27315
# [97]	validation_0-logloss:0.27311
# [98]	validation_0-logloss:0.27309
# [99]	validation_0-logloss:0.27248
# [100]	validation_0-logloss:0.27229
# [101]	validation_0-logloss:0.27189
# [102]	validation_0-logloss:0.27191
# [103]	validation_0-logloss:0.27174
# [104]	validation_0-logloss:0.27153
# [105]	validation_0-logloss:0.27088
# [106]	validation_0-logloss:0.27073
# [107]	validation_0-logloss:0.27067
# [108]	validation_0-logloss:0.27035
# [109]	validation_0-logloss:0.27031
# [110]	validation_0-logloss:0.27013
# [111]	validation_0-logloss:0.27011
# [112]	validation_0-logloss:0.27007
# [113]	validation_0-logloss:0.26990
# [114]	validation_0-logloss:0.27000
# [115]	validation_0-logloss:0.26978
# [116]	validation_0-logloss:0.26966
# [117]	validation_0-logloss:0.26955
# [118]	validation_0-logloss:0.26941
# [119]	validation_0-logloss:0.26940
# [120]	validation_0-logloss:0.26932
# [121]	validation_0-logloss:0.26904
# [122]	validation_0-logloss:0.26894
# [123]	validation_0-logloss:0.26895
# [124]	validation_0-logloss:0.26894
# [125]	validation_0-logloss:0.26888
# [126]	validation_0-logloss:0.26878
# [127]	validation_0-logloss:0.26858
# [128]	validation_0-logloss:0.26831
# [129]	validation_0-logloss:0.26825
# [130]	validation_0-logloss:0.26827
# [131]	validation_0-logloss:0.26814
# [132]	validation_0-logloss:0.26779
# [133]	validation_0-logloss:0.26776
# [134]	validation_0-logloss:0.26727
# [135]	validation_0-logloss:0.26692
# [136]	validation_0-logloss:0.26700
# [137]	validation_0-logloss:0.26687
# [138]	validation_0-logloss:0.26656
# [139]	validation_0-logloss:0.26635
# [140]	validation_0-logloss:0.26635
# [141]	validation_0-logloss:0.26629
# [142]	validation_0-logloss:0.26601
# [143]	validation_0-logloss:0.26605
# [144]	validation_0-logloss:0.26585
# [145]	validation_0-logloss:0.26562
# [146]	validation_0-logloss:0.26554
# [147]	validation_0-logloss:0.26536
# [148]	validation_0-logloss:0.26493
# [149]	validation_0-logloss:0.26482
# [150]	validation_0-logloss:0.26490
# [151]	validation_0-logloss:0.26491
# [152]	validation_0-logloss:0.26492
# [153]	validation_0-logloss:0.26474
# [154]	validation_0-logloss:0.26474
# [155]	validation_0-logloss:0.26478
# [156]	validation_0-logloss:0.26468
# [157]	validation_0-logloss:0.26479
# [158]	validation_0-logloss:0.26441
# [159]	validation_0-logloss:0.26436
# [160]	validation_0-logloss:0.26440
# [161]	validation_0-logloss:0.26433
# [162]	validation_0-logloss:0.26417
# [163]	validation_0-logloss:0.26424
# [164]	validation_0-logloss:0.26426
# [165]	validation_0-logloss:0.26432
# [166]	validation_0-logloss:0.26428
# [167]	validation_0-logloss:0.26430
# [168]	validation_0-logloss:0.26437
# [169]	validation_0-logloss:0.26442
# [170]	validation_0-logloss:0.26431
# [171]	validation_0-logloss:0.26421
# [172]	validation_0-logloss:0.26422
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               gamma=0.1, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=200, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
# Evaluate the best model
best_model = grid_search.best_estimator_
best_model_evaluation = best_model.score(X_test_rus, y_test_rus)
print(f"Best model evaluation score: {best_model_evaluation}")
# Out:
# Best model evaluation score: 0.8756629345904537

# %%
# Evaluate the best model on the test set
y_pred = best_model.predict(X_test_rus)
roc_auc = roc_auc_score(y_test_rus, y_pred)
print(f"ROC AUC: {roc_auc}")
# Out:
# ROC AUC: 0.8757025556792195

# %%
# Calculate accuracy and other classification metrics
accuracy = accuracy_score(y_test_rus, y_pred)
conf_matrix = confusion_matrix(y_test_rus, y_pred)
classification_rep = classification_report(y_test_rus, y_pred)

# %%
print(f"Validation Accuracy: {accuracy}")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(classification_rep)
# Out:
# Validation Accuracy: 0.8756629345904537
# Confusion Matrix:
# [[1485  200]
#  [ 222 1487]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.87      0.88      0.88      1685
#         True       0.88      0.87      0.88      1709
#
#     accuracy                           0.88      3394
#    macro avg       0.88      0.88      0.88      3394
# weighted avg       0.88      0.88      0.88      3394

# %%
from sklearn.metrics import roc_curve

# Plot ROC curve
fpr_rus, tpr_rus, _ = roc_curve(y_test_rus, y_pred)
plt.figure()
plt.plot(fpr_rus, tpr_rus, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) for RUS dataset')
plt.legend(loc="lower right")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a confusion matrix for RUS dataset
conf_matrix_rus = confusion_matrix(y_test_rus, y_pred)

# Create a heatmap for the confusion matrix
sns.heatmap(conf_matrix_rus, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix for RUS dataset")
plt.show()
print(conf_matrix_rus)
# Out:
# [[1485  200]
#  [ 222 1487]]

# %%
# 1. Precision-Recall Curve for RUS dataset
from sklearn.metrics import precision_recall_curve, average_precision_score

# Precision-Recall Curve
precision_rus, recall_rus, _ = precision_recall_curve(y_test_rus, y_pred)
average_precision_rus = average_precision_score(y_test_rus, y_pred)
plt.figure(figsize=(8, 6))
plt.plot(recall_rus, precision_rus, lw=2, label='Precision-Recall Curve (AUC = {0:0.2f})'.format(average_precision_rus))
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve for RUS dataset')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
# F1 Score vs. Threshold
thresholds_rus = np.arange(0, 1.05, 0.05)
f1_scores_rus = [f1_score(y_test_rus, (best_model.predict_proba(X_test_rus)[:, 1] >= t).astype(int)) for t in thresholds_rus]
plt.figure(figsize=(8, 6))
plt.plot(thresholds_rus, f1_scores_rus, marker='o', linestyle='--', color='r')
plt.xlabel('Threshold')
plt.ylabel('F1 Score')
plt.title('F1 Score vs. Threshold for RUS dataset')
plt.grid(True)
plt.show()


print(f"Best Threshold: {best_threshold:.2f}")
print(f"Best F1 Score: {best_f1_score:.4f}")
# Out:
# Best Threshold: 0.30
# Best F1 Score: 0.9895

# %% [markdown]
# The top three features NextOrderYear, NextOrderHour, and NextOrderMonth are all related to the timing of future orders. This highlights the importance of understanding customer purchasing patterns over time to accurately predict churn.

# %%
# Get feature importances from the best_model for RUS dataset
feature_importances_rus = best_model.feature_importances_

# Get feature names from the X_train_rus columns
features_rus = X_train_rus.columns

# Sort feature importances and feature names in descending order of importance
sorted_idx_rus = feature_importances_rus.argsort()[::-1]
feature_importances_rus = feature_importances_rus[sorted_idx_rus]
features_rus = features_rus[sorted_idx_rus]

# Print feature importances and their corresponding feature names
for i in range(len(features_rus)):
    print(f"{i+1}. {features_rus[i]}: {feature_importances_rus[i]:.4f}")
# Out:
# 1. NextOrderYear: 0.4324
# 2. NextOrderHour: 0.1365
# 3. NextOrderMonth: 0.0566
# 4. TotalUniqueOrders: 0.0523
# 5. MinOrderAmount: 0.0347
# 6. DaysSinceFirstPurchase: 0.0278
# 7. InvoiceYear: 0.0273
# 8. CumulativeTime: 0.0250
# 9. NextOrderDay: 0.0180
# 10. Quantity: 0.0175
# 11. TotalPurchase: 0.0153
# 12. InvoiceMonth: 0.0141
# 13. TotalOrderAmountLast30Days: 0.0138
# 14. PriorOrderCount: 0.0128
# 15. TotalOrderQuantityLast30Days: 0.0119
# 16. TotalOrdersLast1Week: 0.0119
# 17. MaxAmountLast30Days: 0.0105
# 18. TotalOrdersLast1Month: 0.0100
# 19. MeanAmountPriorToDate: 0.0099
# 20. InvoiceHour: 0.0073
# 21. Country: 0.0072
# 22. AverageOrderAmount: 0.0065
# 23. OrderStdDeviation: 0.0057
# 24. InvoiceDay: 0.0054
# 25. TimeSinceLastOrder: 0.0052
# 26. UnitPrice: 0.0046
# 27. TotalAmountLast1Month: 0.0044
# 28. PrevMeanAmount: 0.0044
# 29. MinAmountPriorToDate: 0.0039
# 30. TotalAmountLast1Week: 0.0038
# 31. MaxOrderAmount: 0.0037
# 32. AverageOrderDuration: 0.0000
# 33. OverMaxAmountLast30Days: 0.0000

# %%
# Create the bar plot for feature importances in RUS dataset
plt.figure(figsize=(10, 6))
plt.barh(range(len(features_rus)), feature_importances_rus, align='center')
plt.yticks(range(len(features_rus)), features_rus)
plt.xlabel('Feature Importance (RUS)')
plt.title('Feature Importances (RUS)')
plt.grid(True)
plt.show()

# %% [markdown]
# # Final Report

# %% [markdown]
# The evaluation metrics show that the model trained with RUS had slightly lower accuracy and F1-score compared to the initial model. However, it achieved a balanced performance with similar precision and recall for both classes, as indicated by the confusion matrix and classification report.
#
# **Purpose of Model Evaluation:**
# The evaluation was performed to compare the performance of the initial model trained on the full dataset to the model trained with RUS.
#
# The purpose was to:
# 1. **Address Class Imbalance:** Determine if balancing the dataset with RUS improves model performance and reduces bias towards the majority class.
# 2. **Optimize Model Performance:** Identify the best hyperparameters through GridSearchCV to maximize predictive accuracy and generalization ability on unseen data.
# 3. **Enhance Model Interpretability:** Understand feature importance and gain insights into factors driving customer churn in the e-commerce platform.
#
# ### Comparison and Analysis
#
# #### Before RUS
# - Non-Churned Customers in the Validation Set: 2,530
# - Churned Customers in the Validation Set: 118,106
# - **Accuracy:** High (97.93%) but potentially biased towards the majority class (non-churned customers).
# - **F1-Score:** High (0.9895) but mainly due to excellent performance on the majority class.
# - **ROC AUC Score:** High (0.876), indicating good overall performance.
# - **Confusion Matrix and Classification Report:** Showed poor recall for the minority class (churned customers).
#
# #### After RUS
# - Non-Churned Customers: 1485 (True Negatives) + 200 (False Positives) = 1685
# - Churned Customers: 1487 (True Positives) + 222 (False Negatives) = 1709
# - **Accuracy:** Reduced to 87.57%, reflecting a more balanced performance across both classes.
# - **F1-Score:** More balanced, reflecting better performance on both classes.
# - **ROC AUC Score:** Remained consistent at 0.876, indicating stable model performance.
# - **Confusion Matrix and Classification Report:** Improved recall for the minority class (churned customers), indicating the model's improved ability to correctly identify churned customers.
#
# ### Conclusion
#
# Applying Random UnderSampling (RUS) addressed the class imbalance issue, leading to a more balanced and fair model. Although the overall accuracy decreased, the model's ability to correctly identify churned customers improved significantly, making it more useful for real-world applications where identifying churn is important.
